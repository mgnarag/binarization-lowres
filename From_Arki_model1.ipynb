# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/binarization-lowres/blob/main/From_Arki_model1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/Architectural_designs/From Arki/"

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

epoch = 100
model_number = 1
size = 32

def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,2.4):
        for i in np.arange(0,int(width/size)+1,2.4):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)


    return data

def crop_(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,2.4):
        for i in np.arange(0,int(width/size)+1,2.4):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            #im1 = im1/4
            data.append(im1)


    return data



input = np.array(crop_(ImageOps.grayscale(Image.open(file_path + "Rizal_input.png"))))
print("Done reading the input of size = ", input.shape)

output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Rizal_output.png"))))
print("Done reading the output of size = ", input.shape)

train_input = []
test_input = []
for i in range(0,len(input)):
    if i % 4 == 0:
        test_input.append(input[i])
    else:
        train_input.append(input[i])

train_input = np.array(train_input)
test_input = np.array(test_input)

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)

train_output = []
test_output = []
for i in range(0,len(output)):
    if i % 4 == 0:
        test_output.append(output[i])
    else:
        train_output.append(output[i])

train_output = np.array(train_output)
test_output = np.array(test_output)

print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)
# Out:
# Done reading the input of size =  (19824, 32, 32)
# Done reading the output of size =  (19824, 32, 32)
# Done reading the train input of size =  (14868, 32, 32)
# Done reading the test input of size =  (4956, 32, 32)
# Done reading the train output of size =  (14868, 32, 32)
# Done reading the test output of size =  (4956, 32, 32)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((train_input[i+6000]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+6000]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
start = time.time()
import tensorflow as tf

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model

class autoenc(Model):
  def __init__(self):
    super(autoenc, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Input(shape=(size, size, 1)),
      layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=2),
      layers.Conv2D(128, (3, 3), activation='relu', padding='same', strides=2)])

    self.decoder = tf.keras.Sequential([
      layers.Conv2DTranspose(128, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = autoenc()


autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

model = autoencoder.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output))

autoencoder.encoder.summary()


autoencoder.save(file_path + '1 Models/' + 'autoencoder_' + str(model_number))

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + '2 Loss/'+'loss_'+ str(model_number) + '.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path + '3 Validation loss/' +'val_loss_'+ str(model_number) + '.csv')

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")
# Out:
# Epoch 1/100
# 465/465 [==============================] - 6s 9ms/step - loss: 0.0385 - val_loss: 0.0269
# Epoch 2/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0247 - val_loss: 0.0227
# Epoch 3/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0224 - val_loss: 0.0220
# Epoch 4/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0217 - val_loss: 0.0217
# Epoch 5/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0211 - val_loss: 0.0212
# Epoch 6/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0207 - val_loss: 0.0217
# Epoch 7/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0202 - val_loss: 0.0209
# Epoch 8/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0199 - val_loss: 0.0203
# Epoch 9/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0198 - val_loss: 0.0204
# Epoch 10/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0195 - val_loss: 0.0208
# Epoch 11/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0194 - val_loss: 0.0204
# Epoch 12/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0192 - val_loss: 0.0199
# Epoch 13/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0190 - val_loss: 0.0211
# Epoch 14/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0189 - val_loss: 0.0196
# Epoch 15/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0190 - val_loss: 0.0198
# Epoch 16/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0189 - val_loss: 0.0202
# Epoch 17/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0188 - val_loss: 0.0208
# Epoch 18/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0186 - val_loss: 0.0197
# Epoch 19/100
# 465/465 [==============================] - 4s 9ms/step - loss: 0.0185 - val_loss: 0.0194
# Epoch 20/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0184 - val_loss: 0.0196
# Epoch 21/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0184 - val_loss: 0.0196
# Epoch 22/100
# 465/465 [==============================] - 4s 9ms/step - loss: 0.0184 - val_loss: 0.0198
# Epoch 23/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0183 - val_loss: 0.0197
# Epoch 24/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0182 - val_loss: 0.0196
# Epoch 25/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0182 - val_loss: 0.0198
# Epoch 26/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0182 - val_loss: 0.0194
# Epoch 27/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0181 - val_loss: 0.0193
# Epoch 28/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0181 - val_loss: 0.0196
# Epoch 29/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0180 - val_loss: 0.0194
# Epoch 30/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0181 - val_loss: 0.0195
# Epoch 31/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0180 - val_loss: 0.0194
# Epoch 32/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0179 - val_loss: 0.0200
# Epoch 33/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0179 - val_loss: 0.0196
# Epoch 34/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0178 - val_loss: 0.0195
# Epoch 35/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0177 - val_loss: 0.0194
# Epoch 36/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0176 - val_loss: 0.0195
# Epoch 37/100
# 465/465 [==============================] - 3s 8ms/step - loss: 0.0176 - val_loss: 0.0193
# Epoch 38/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0176 - val_loss: 0.0195
# Epoch 39/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0175 - val_loss: 0.0193
# Epoch 40/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0174 - val_loss: 0.0194
# Epoch 41/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0174 - val_loss: 0.0194
# Epoch 42/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0174 - val_loss: 0.0193
# Epoch 43/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0174 - val_loss: 0.0195
# Epoch 44/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0172 - val_loss: 0.0193
# Epoch 45/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0173 - val_loss: 0.0194
# Epoch 46/100
# 465/465 [==============================] - 4s 9ms/step - loss: 0.0172 - val_loss: 0.0198
# Epoch 47/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0171 - val_loss: 0.0193
# Epoch 48/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0171 - val_loss: 0.0194
# Epoch 49/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0169 - val_loss: 0.0193
# Epoch 50/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0170 - val_loss: 0.0195
# Epoch 51/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0169 - val_loss: 0.0193
# Epoch 52/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0168 - val_loss: 0.0194
# Epoch 53/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0167 - val_loss: 0.0196
# Epoch 54/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0167 - val_loss: 0.0195
# Epoch 55/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0167 - val_loss: 0.0193
# Epoch 56/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0167 - val_loss: 0.0196
# Epoch 57/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0166 - val_loss: 0.0195
# Epoch 58/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0165 - val_loss: 0.0197
# Epoch 59/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0164 - val_loss: 0.0195
# Epoch 60/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0165 - val_loss: 0.0199
# Epoch 61/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0163 - val_loss: 0.0197
# Epoch 62/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0162 - val_loss: 0.0194
# Epoch 63/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0162 - val_loss: 0.0195
# Epoch 64/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0162 - val_loss: 0.0196
# Epoch 65/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0161 - val_loss: 0.0198
# Epoch 66/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0160 - val_loss: 0.0196
# Epoch 67/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0160 - val_loss: 0.0195
# Epoch 68/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0159 - val_loss: 0.0198
# Epoch 69/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0158 - val_loss: 0.0195
# Epoch 70/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0158 - val_loss: 0.0200
# Epoch 71/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0158 - val_loss: 0.0199
# Epoch 72/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0156 - val_loss: 0.0200
# Epoch 73/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0155 - val_loss: 0.0204
# Epoch 74/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0154 - val_loss: 0.0198
# Epoch 75/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0154 - val_loss: 0.0203
# Epoch 76/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0153 - val_loss: 0.0199
# Epoch 77/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0153 - val_loss: 0.0200
# Epoch 78/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0152 - val_loss: 0.0205
# Epoch 79/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0151 - val_loss: 0.0202
# Epoch 80/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0150 - val_loss: 0.0204
# Epoch 81/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0150 - val_loss: 0.0202
# Epoch 82/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0149 - val_loss: 0.0202
# Epoch 83/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0148 - val_loss: 0.0206
# Epoch 84/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0148 - val_loss: 0.0203
# Epoch 85/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0146 - val_loss: 0.0204
# Epoch 86/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0146 - val_loss: 0.0204
# Epoch 87/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0146 - val_loss: 0.0204
# Epoch 88/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0144 - val_loss: 0.0204
# Epoch 89/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0144 - val_loss: 0.0206
# Epoch 90/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0143 - val_loss: 0.0213
# Epoch 91/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0142 - val_loss: 0.0206
# Epoch 92/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0141 - val_loss: 0.0207
# Epoch 93/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0141 - val_loss: 0.0207
# Epoch 94/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0140 - val_loss: 0.0208
# Epoch 95/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0139 - val_loss: 0.0209
# Epoch 96/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0138 - val_loss: 0.0209
# Epoch 97/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0138 - val_loss: 0.0211
# Epoch 98/100
# 465/465 [==============================] - 4s 8ms/step - loss: 0.0137 - val_loss: 0.0212
# Epoch 99/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0136 - val_loss: 0.0212
# Epoch 100/100
# 465/465 [==============================] - 3s 7ms/step - loss: 0.0135 - val_loss: 0.0211
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 16, 16, 64)        640
#
#  conv2d_10 (Conv2D)          (None, 8, 8, 128)         73856
#
# =================================================================
# Total params: 74496 (291.00 KB)
# Trainable params: 74496 (291.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# The time of execution of above program is : 384.66552233695984 seconds
