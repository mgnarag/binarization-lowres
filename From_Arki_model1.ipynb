# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/binarization-lowres/blob/main/From_Arki_model1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/Architectural_designs/From Arki/"

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

epoch = 100
model_number = 1
size = 32

def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,2.25):
        for i in np.arange(0,int(width/size)+1,2.25):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)


    return data

def crop_(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,2.25):
        for i in np.arange(0,int(width/size)+1,2.5):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            im1 = im1/4
            data.append(im1)


    return data



input = np.array(crop_(ImageOps.grayscale(Image.open(file_path + "Rizal_input.png"))))
print("Done reading the input of size = ", input.shape)

output = np.array(crop_(ImageOps.grayscale(Image.open(file_path + "Rizal_output.png"))))
print("Done reading the output of size = ", input.shape)

train_input = []
test_input = []
for i in range(0,len(input)):
    if i % 4 == 0:
        test_input.append(input[i])
    else:
        train_input.append(input[i])

train_input = np.array(train_input)
test_input = np.array(test_input)

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)

train_output = []
test_output = []
for i in range(0,len(output)):
    if i % 4 == 0:
        test_output.append(output[i])
    else:
        train_output.append(output[i])

train_output = np.array(train_output)
test_output = np.array(test_output)

print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)
# Out:
# Done reading the input of size =  (20286, 32, 32)
# Done reading the output of size =  (20286, 32, 32)
# Done reading the train input of size =  (15214, 32, 32)
# Done reading the test input of size =  (5072, 32, 32)
# Done reading the train output of size =  (15214, 32, 32)
# Done reading the test output of size =  (5072, 32, 32)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((train_input[i+4000]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+4000]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
start = time.time()
import tensorflow as tf

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model

class autoenc(Model):
  def __init__(self):
    super(autoenc, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Input(shape=(size, size, 1)),
      layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=2),
      layers.Conv2D(128, (3, 3), activation='relu', padding='same', strides=2)])

    self.decoder = tf.keras.Sequential([
      layers.Conv2DTranspose(128, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = autoenc()


autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

model = autoencoder.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output))

autoencoder.encoder.summary()


autoencoder.save(file_path + '1 Models/' + 'autoencoder_' + str(model_number))

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + '2 Loss/'+'loss_'+ str(model_number) + '.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path + '3 Validation loss/' +'val_loss_'+ str(model_number) + '.csv')

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")
# Out:
# Epoch 1/100
# 476/476 [==============================] - 14s 8ms/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 2/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 3/100
# 476/476 [==============================] - 4s 7ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 4/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 5/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 6/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 7/100
# 476/476 [==============================] - 4s 8ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 8/100
# 476/476 [==============================] - 3s 6ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 9/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 10/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 11/100
# 476/476 [==============================] - 4s 8ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 12/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 13/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 14/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 15/100
# 476/476 [==============================] - 4s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 16/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 17/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 18/100
# 476/476 [==============================] - 4s 8ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 19/100
# 476/476 [==============================] - 5s 9ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 20/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 21/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 22/100
# 476/476 [==============================] - 4s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 23/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 24/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 25/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 26/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 27/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 28/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 29/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 30/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 31/100
# 476/476 [==============================] - 4s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 32/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 33/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 34/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 35/100
# 476/476 [==============================] - 4s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 36/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 37/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 38/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 39/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 40/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 41/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 42/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 43/100
# 476/476 [==============================] - 4s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 44/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 45/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 46/100
# 476/476 [==============================] - 4s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 47/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 48/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 49/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 50/100
# 476/476 [==============================] - 4s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 51/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 52/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 53/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 54/100
# 476/476 [==============================] - 4s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 55/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 56/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 57/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 58/100
# 476/476 [==============================] - 4s 8ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 59/100
# 476/476 [==============================] - 4s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 60/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 61/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 62/100
# 476/476 [==============================] - 4s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 63/100
# 476/476 [==============================] - 4s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 64/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 65/100
# 476/476 [==============================] - 3s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 66/100
# 476/476 [==============================] - 4s 8ms/step - loss: 9.9829e-04 - val_loss: 0.0012
# Epoch 67/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.9726e-04 - val_loss: 0.0011
# Epoch 68/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.9161e-04 - val_loss: 0.0012
# Epoch 69/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.8910e-04 - val_loss: 0.0011
# Epoch 70/100
# 476/476 [==============================] - 4s 8ms/step - loss: 9.8481e-04 - val_loss: 0.0011
# Epoch 71/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.8336e-04 - val_loss: 0.0011
# Epoch 72/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.8193e-04 - val_loss: 0.0011
# Epoch 73/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.8035e-04 - val_loss: 0.0011
# Epoch 74/100
# 476/476 [==============================] - 4s 8ms/step - loss: 9.7000e-04 - val_loss: 0.0011
# Epoch 75/100
# 476/476 [==============================] - 4s 7ms/step - loss: 9.6917e-04 - val_loss: 0.0011
# Epoch 76/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.6651e-04 - val_loss: 0.0011
# Epoch 77/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.6060e-04 - val_loss: 0.0011
# Epoch 78/100
# 476/476 [==============================] - 4s 8ms/step - loss: 9.5998e-04 - val_loss: 0.0011
# Epoch 79/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.5485e-04 - val_loss: 0.0011
# Epoch 80/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.4962e-04 - val_loss: 0.0011
# Epoch 81/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.4749e-04 - val_loss: 0.0012
# Epoch 82/100
# 476/476 [==============================] - 4s 8ms/step - loss: 9.4662e-04 - val_loss: 0.0011
# Epoch 83/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.3921e-04 - val_loss: 0.0012
# Epoch 84/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.3853e-04 - val_loss: 0.0012
# Epoch 85/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.3596e-04 - val_loss: 0.0011
# Epoch 86/100
# 476/476 [==============================] - 4s 8ms/step - loss: 9.2860e-04 - val_loss: 0.0012
# Epoch 87/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.2788e-04 - val_loss: 0.0012
# Epoch 88/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.2071e-04 - val_loss: 0.0011
# Epoch 89/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.1748e-04 - val_loss: 0.0011
# Epoch 90/100
# 476/476 [==============================] - 4s 8ms/step - loss: 9.1397e-04 - val_loss: 0.0012
# Epoch 91/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.0921e-04 - val_loss: 0.0012
# Epoch 92/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.0338e-04 - val_loss: 0.0012
# Epoch 93/100
# 476/476 [==============================] - 3s 7ms/step - loss: 9.0363e-04 - val_loss: 0.0012
# Epoch 94/100
# 476/476 [==============================] - 4s 8ms/step - loss: 9.0236e-04 - val_loss: 0.0012
# Epoch 95/100
# 476/476 [==============================] - 3s 7ms/step - loss: 8.9465e-04 - val_loss: 0.0012
# Epoch 96/100
# 476/476 [==============================] - 3s 7ms/step - loss: 8.8739e-04 - val_loss: 0.0012
# Epoch 97/100
# 476/476 [==============================] - 3s 7ms/step - loss: 8.8813e-04 - val_loss: 0.0012
# Epoch 98/100
# 476/476 [==============================] - 4s 8ms/step - loss: 8.8220e-04 - val_loss: 0.0012
# Epoch 99/100
# 476/476 [==============================] - 3s 7ms/step - loss: 8.7944e-04 - val_loss: 0.0012
# Epoch 100/100
# 476/476 [==============================] - 3s 7ms/step - loss: 8.7284e-04 - val_loss: 0.0012
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 16, 16, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 128)         73856
#
# =================================================================
# Total params: 74496 (291.00 KB)
# Trainable params: 74496 (291.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# The time of execution of above program is : 355.4311077594757 seconds
