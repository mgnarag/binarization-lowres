# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/binarization-lowres/blob/main/From_Arki_model3_t1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/Architectural_designs/From Arki/"

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

epoch = 100
model_number = 3
size = 64

def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.625):
        for i in np.arange(0,int(width/size)+1,0.625):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)


    return data

def crop_(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.625):
        for i in np.arange(0,int(width/size)+1,0.625):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            im1 = im1/4
            data.append(im1)


    return data



train_input = np.array(crop_(ImageOps.grayscale(Image.open(file_path + "Trial 1/Rizal_input_train.png"))))
print("Done reading the  training input of size = ", train_input.shape)

train_output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Trial 1/Rizal_output_train.png"))))
print("Done reading the  training out of size = ", train_output.shape)

test_input = np.array(crop_(ImageOps.grayscale(Image.open(file_path + "Trial 1/Rizal_input_test.png"))))
print("Done reading the  test input of size = ", test_input.shape)

test_output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Trial 1/Rizal_output_test.png"))))
print("Done reading the  test output of size = ", test_output.shape)
# Out:
# Done reading the  training input of size =  (12800, 64, 64)
# Done reading the  training out of size =  (12800, 64, 64)
# Done reading the  test input of size =  (5832, 64, 64)
# Done reading the  test output of size =  (5832, 64, 64)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((train_input[i+10000]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+10000]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
start = time.time()
import tensorflow as tf

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model



class autoenc(Model):
  def __init__(self):
    super(autoenc, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Input(shape=(size, size, 1)),
      layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=2),
      layers.Conv2D(128, (3, 3), activation='relu', padding='same', strides=2),
      layers.Conv2D(256, (3, 3), activation='relu', padding='same', strides=2)])

    self.decoder = tf.keras.Sequential([
      layers.Conv2DTranspose(256, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2DTranspose(128, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = autoenc()


autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

model = autoencoder.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output))

autoencoder.encoder.summary()


autoencoder.save(file_path + '1 Models/' + 'autoencoder_' + str(model_number))

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + '2 Loss/'+'loss_'+ str(model_number) + '.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path + '3 Validation loss/' +'val_loss_'+ str(model_number) + '.csv')

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")
# Out:
# Epoch 1/100
# 400/400 [==============================] - 17s 30ms/step - loss: 0.0578 - val_loss: 0.0282
# Epoch 2/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0255 - val_loss: 0.0195
# Epoch 3/100
# 400/400 [==============================] - 10s 26ms/step - loss: 0.0216 - val_loss: 0.0224
# Epoch 4/100
# 400/400 [==============================] - 11s 26ms/step - loss: 0.0196 - val_loss: 0.0213
# Epoch 5/100
# 400/400 [==============================] - 12s 29ms/step - loss: 0.0184 - val_loss: 0.0155
# Epoch 6/100
# 400/400 [==============================] - 12s 29ms/step - loss: 0.0177 - val_loss: 0.0137
# Epoch 7/100
# 400/400 [==============================] - 11s 29ms/step - loss: 0.0175 - val_loss: 0.0135
# Epoch 8/100
# 400/400 [==============================] - 11s 27ms/step - loss: 0.0169 - val_loss: 0.0135
# Epoch 9/100
# 400/400 [==============================] - 11s 27ms/step - loss: 0.0166 - val_loss: 0.0137
# Epoch 10/100
# 400/400 [==============================] - 12s 29ms/step - loss: 0.0162 - val_loss: 0.0132
# Epoch 11/100
# 400/400 [==============================] - 12s 29ms/step - loss: 0.0159 - val_loss: 0.0134
# Epoch 12/100
# 400/400 [==============================] - 12s 29ms/step - loss: 0.0157 - val_loss: 0.0133
# Epoch 13/100
# 400/400 [==============================] - 12s 29ms/step - loss: 0.0155 - val_loss: 0.0136
# Epoch 14/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0151 - val_loss: 0.0133
# Epoch 15/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0148 - val_loss: 0.0136
# Epoch 16/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0145 - val_loss: 0.0132
# Epoch 17/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0140 - val_loss: 0.0136
# Epoch 18/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0137 - val_loss: 0.0136
# Epoch 19/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0133 - val_loss: 0.0142
# Epoch 20/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0130 - val_loss: 0.0140
# Epoch 21/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0125 - val_loss: 0.0151
# Epoch 22/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0120 - val_loss: 0.0147
# Epoch 23/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0116 - val_loss: 0.0154
# Epoch 24/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0112 - val_loss: 0.0151
# Epoch 25/100
# 400/400 [==============================] - 12s 31ms/step - loss: 0.0107 - val_loss: 0.0150
# Epoch 26/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0103 - val_loss: 0.0153
# Epoch 27/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0099 - val_loss: 0.0156
# Epoch 28/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0096 - val_loss: 0.0155
# Epoch 29/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0095 - val_loss: 0.0162
# Epoch 30/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0089 - val_loss: 0.0161
# Epoch 31/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0086 - val_loss: 0.0163
# Epoch 32/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0083 - val_loss: 0.0164
# Epoch 33/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0080 - val_loss: 0.0164
# Epoch 34/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0077 - val_loss: 0.0167
# Epoch 35/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0075 - val_loss: 0.0168
# Epoch 36/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0072 - val_loss: 0.0169
# Epoch 37/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0069 - val_loss: 0.0170
# Epoch 38/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0068 - val_loss: 0.0171
# Epoch 39/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0068 - val_loss: 0.0185
# Epoch 40/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0065 - val_loss: 0.0179
# Epoch 41/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0062 - val_loss: 0.0177
# Epoch 42/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0060 - val_loss: 0.0179
# Epoch 43/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0058 - val_loss: 0.0180
# Epoch 44/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0057 - val_loss: 0.0183
# Epoch 45/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0055 - val_loss: 0.0178
# Epoch 46/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0053 - val_loss: 0.0180
# Epoch 47/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0052 - val_loss: 0.0182
# Epoch 48/100
# 400/400 [==============================] - 12s 29ms/step - loss: 0.0051 - val_loss: 0.0180
# Epoch 49/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0050 - val_loss: 0.0182
# Epoch 50/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0048 - val_loss: 0.0182
# Epoch 51/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0047 - val_loss: 0.0180
# Epoch 52/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0046 - val_loss: 0.0183
# Epoch 53/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0045 - val_loss: 0.0184
# Epoch 54/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0045 - val_loss: 0.0184
# Epoch 55/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0043 - val_loss: 0.0182
# Epoch 56/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0042 - val_loss: 0.0186
# Epoch 57/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0041 - val_loss: 0.0185
# Epoch 58/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0040 - val_loss: 0.0184
# Epoch 59/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0040 - val_loss: 0.0191
# Epoch 60/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0041 - val_loss: 0.0187
# Epoch 61/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0038 - val_loss: 0.0186
# Epoch 62/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0038 - val_loss: 0.0186
# Epoch 63/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0037 - val_loss: 0.0190
# Epoch 64/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0036 - val_loss: 0.0189
# Epoch 65/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0036 - val_loss: 0.0190
# Epoch 66/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0035 - val_loss: 0.0188
# Epoch 67/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0035 - val_loss: 0.0190
# Epoch 68/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0034 - val_loss: 0.0191
# Epoch 69/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0034 - val_loss: 0.0189
# Epoch 70/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0034 - val_loss: 0.0189
# Epoch 71/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0032 - val_loss: 0.0190
# Epoch 72/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0032 - val_loss: 0.0191
# Epoch 73/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0032 - val_loss: 0.0193
# Epoch 74/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0031 - val_loss: 0.0191
# Epoch 75/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0031 - val_loss: 0.0192
# Epoch 76/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0030 - val_loss: 0.0191
# Epoch 77/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0030 - val_loss: 0.0191
# Epoch 78/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0029 - val_loss: 0.0192
# Epoch 79/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0030 - val_loss: 0.0191
# Epoch 80/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0030 - val_loss: 0.0192
# Epoch 81/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0029 - val_loss: 0.0193
# Epoch 82/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0028 - val_loss: 0.0194
# Epoch 83/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0028 - val_loss: 0.0192
# Epoch 84/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0033 - val_loss: 0.0192
# Epoch 85/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0028 - val_loss: 0.0195
# Epoch 86/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0027 - val_loss: 0.0196
# Epoch 87/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0027 - val_loss: 0.0195
# Epoch 88/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0026 - val_loss: 0.0194
# Epoch 89/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0026 - val_loss: 0.0196
# Epoch 90/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0026 - val_loss: 0.0197
# Epoch 91/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0027 - val_loss: 0.0222
# Epoch 92/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0035 - val_loss: 0.0205
# Epoch 93/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0026 - val_loss: 0.0202
# Epoch 94/100
# 400/400 [==============================] - 12s 29ms/step - loss: 0.0025 - val_loss: 0.0200
# Epoch 95/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0025 - val_loss: 0.0197
# Epoch 96/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0024 - val_loss: 0.0200
# Epoch 97/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0024 - val_loss: 0.0199
# Epoch 98/100
# 400/400 [==============================] - 11s 28ms/step - loss: 0.0025 - val_loss: 0.0198
# Epoch 99/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0024 - val_loss: 0.0201
# Epoch 100/100
# 400/400 [==============================] - 12s 30ms/step - loss: 0.0024 - val_loss: 0.0200
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 32, 32, 64)        640
#
#  conv2d_5 (Conv2D)           (None, 16, 16, 128)       73856
#
#  conv2d_6 (Conv2D)           (None, 8, 8, 256)         295168
#
# =================================================================
# Total params: 369664 (1.41 MB)
# Trainable params: 369664 (1.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# The time of execution of above program is : 1225.813529253006 seconds
