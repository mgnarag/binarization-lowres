# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/binarization-lowres/blob/main/From_Arki_model5_red.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/Architectural_designs/From Arki/"

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

epoch = 100
model_number = 5
size = 128

def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.33):
        for i in np.arange(0,int(width/size)+1,0.33):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)


    return data

def crop_(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.33):
        for i in np.arange(0,int(width/size)+1,0.33):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            #im1 = im1/4
            data.append(im1)


    return data



input = np.array(crop_(ImageOps.grayscale(Image.open(file_path + "red_Rizal_input.png"))))
print("Done reading the input of size = ", input.shape)

output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Rizal_output.png"))))
print("Done reading the output of size = ", input.shape)

train_input = []
test_input = []
for i in range(0,len(input)):
    if i % 4 == 0:
        test_input.append(input[i])
    else:
        train_input.append(input[i])

train_input = np.array(train_input)
test_input = np.array(test_input)

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)

train_output = []
test_output = []
for i in range(0,len(output)):
    if i % 4 == 0:
        test_output.append(output[i])
    else:
        train_output.append(output[i])

train_output = np.array(train_output)
test_output = np.array(test_output)

print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)
# Out:
# Done reading the input of size =  (17050, 128, 128)
# Done reading the output of size =  (17050, 128, 128)
# Done reading the train input of size =  (12787, 128, 128)
# Done reading the test input of size =  (4263, 128, 128)
# Done reading the train output of size =  (12787, 128, 128)
# Done reading the test output of size =  (4263, 128, 128)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((test_input[i+1000]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((test_output[i+1000]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
start = time.time()
import tensorflow as tf

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model

class autoenc(Model):
  def __init__(self):
    super(autoenc, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Input(shape=(size, size, 1)),
      layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=2),
      layers.Conv2D(128, (3, 3), activation='relu', padding='same', strides=2),
      layers.Conv2D(256, (3, 3), activation='relu', padding='same', strides=2)])

    self.decoder = tf.keras.Sequential([
      layers.Conv2DTranspose(256, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2DTranspose(128, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = autoenc()


autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

model = autoencoder.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output))

autoencoder.encoder.summary()


autoencoder.save(file_path + '1 Models/' + 'autoencoder_' + str(model_number)+'_red')

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + '2 Loss/'+'loss_'+ str(model_number) + '_red.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path + '3 Validation loss/' +'val_loss_'+ str(model_number) + '_red.csv')

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")
# Out:
# Epoch 1/100
# 400/400 [==============================] - 54s 100ms/step - loss: 0.0727 - val_loss: 0.0701
# Epoch 2/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0579 - val_loss: 0.0562
# Epoch 3/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0560 - val_loss: 0.0586
# Epoch 4/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0582 - val_loss: 0.0570
# Epoch 5/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0551
# Epoch 6/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0551 - val_loss: 0.0551
# Epoch 7/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0551 - val_loss: 0.0551
# Epoch 8/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0551 - val_loss: 0.0551
# Epoch 9/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0552 - val_loss: 0.0551
# Epoch 10/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0551 - val_loss: 0.0551
# Epoch 11/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0551 - val_loss: 0.0551
# Epoch 12/100
# 400/400 [==============================] - 38s 95ms/step - loss: 0.0551 - val_loss: 0.0551
# Epoch 13/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0553 - val_loss: 0.0551
# Epoch 14/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0551 - val_loss: 0.0551
# Epoch 15/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0551 - val_loss: 0.0551
# Epoch 16/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0551 - val_loss: 0.0551
# Epoch 17/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0552 - val_loss: 0.0553
# Epoch 18/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0554 - val_loss: 0.0551
# Epoch 19/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0555 - val_loss: 0.0554
# Epoch 20/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0553 - val_loss: 0.0552
# Epoch 21/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0553 - val_loss: 0.0552
# Epoch 22/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0553 - val_loss: 0.0552
# Epoch 23/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0553 - val_loss: 0.0562
# Epoch 24/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0555 - val_loss: 0.0558
# Epoch 25/100
# 400/400 [==============================] - 38s 95ms/step - loss: 0.0553 - val_loss: 0.0552
# Epoch 26/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0555 - val_loss: 0.0553
# Epoch 27/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0553 - val_loss: 0.0553
# Epoch 28/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0553 - val_loss: 0.0553
# Epoch 29/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0556
# Epoch 30/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0556 - val_loss: 0.0555
# Epoch 31/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0555 - val_loss: 0.0555
# Epoch 32/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 33/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0553 - val_loss: 0.0552
# Epoch 34/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0558
# Epoch 35/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0557 - val_loss: 0.0553
# Epoch 36/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0556
# Epoch 37/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 38/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 39/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0554
# Epoch 40/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 41/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 42/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 43/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 44/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 45/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 46/100
# 400/400 [==============================] - 38s 95ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 47/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 48/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 49/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 50/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 51/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 52/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 53/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 54/100
# 400/400 [==============================] - 38s 95ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 55/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 56/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 57/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 58/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 59/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 60/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 61/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 62/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 63/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 64/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 65/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 66/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 67/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 68/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 69/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 70/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 71/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 72/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 73/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 74/100
# 400/400 [==============================] - 38s 95ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 75/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 76/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 77/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 78/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 79/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 80/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 81/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 82/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 83/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 84/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 85/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 86/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 87/100
# 400/400 [==============================] - 38s 95ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 88/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 89/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 90/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 91/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 92/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 93/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 94/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 95/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 96/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 97/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0554 - val_loss: 0.0553
# Epoch 98/100
# 400/400 [==============================] - 38s 94ms/step - loss: 0.0555 - val_loss: 0.0555
# Epoch 99/100
# 400/400 [==============================] - 37s 92ms/step - loss: 0.0556 - val_loss: 0.0555
# Epoch 100/100
# 400/400 [==============================] - 37s 93ms/step - loss: 0.0556 - val_loss: 0.0556
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       73856
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)       295168
#
# =================================================================
# Total params: 369664 (1.41 MB)
# Trainable params: 369664 (1.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# The time of execution of above program is : 3761.8523378372192 seconds
