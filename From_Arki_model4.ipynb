# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/binarization-lowres/blob/main/From_Arki_model4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/Architectural_designs/From Arki/"

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

epoch = 100
model_number = 4
size = 64

def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.50):
        for i in np.arange(0,int(width/size)+1,0.50):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)


    return data

def crop_(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.50):
        for i in np.arange(0,int(width/size)+1,0.50):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            im1 = im1/4
            data.append(im1)


    return data



train_input = np.array(crop_(ImageOps.grayscale(Image.open(file_path + "Trial 2/Rizal_input_train.png"))))
print("Done reading the  training input of size = ", train_input.shape)

train_output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Trial 2/Rizal_output_train.png"))))
print("Done reading the  training out of size = ", train_output.shape)

test_input = np.array(crop_(ImageOps.grayscale(Image.open(file_path + "Trial 2/Rizal_input_test.png"))))
print("Done reading the  test input of size = ", test_input.shape)

test_output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Trial 2/Rizal_output_test.png"))))
print("Done reading the  test output of size = ", test_output.shape)
# Out:
# Done reading the  training input of size =  (10608, 64, 64)
# Done reading the  training out of size =  (10608, 64, 64)
# Done reading the  test input of size =  (5120, 64, 64)
# Done reading the  test output of size =  (5120, 64, 64)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((train_input[i+10000]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+10000]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
start = time.time()
import tensorflow as tf

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model

class autoenc(Model):
  def __init__(self):
    super(autoenc, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Input(shape=(size, size, 1)),
      layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=2)])

    self.decoder = tf.keras.Sequential([
      layers.Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = autoenc()


autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

model = autoencoder.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output))

autoencoder.encoder.summary()


autoencoder.save(file_path + '1 Models/' + 'autoencoder_' + str(model_number))

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + '2 Loss/'+'loss_'+ str(model_number) + '.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path + '3 Validation loss/' +'val_loss_'+ str(model_number) + '.csv')

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")
# Out:
# Epoch 1/100
# 332/332 [==============================] - 6s 13ms/step - loss: 0.0506 - val_loss: 0.0355
# Epoch 2/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0314 - val_loss: 0.0289
# Epoch 3/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0285 - val_loss: 0.0272
# Epoch 4/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0272 - val_loss: 0.0277
# Epoch 5/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0266 - val_loss: 0.0256
# Epoch 6/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0262 - val_loss: 0.0265
# Epoch 7/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0259 - val_loss: 0.0248
# Epoch 8/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0256 - val_loss: 0.0276
# Epoch 9/100
# 332/332 [==============================] - 4s 14ms/step - loss: 0.0254 - val_loss: 0.0256
# Epoch 10/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0251 - val_loss: 0.0242
# Epoch 11/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0250 - val_loss: 0.0249
# Epoch 12/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0248 - val_loss: 0.0243
# Epoch 13/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0246 - val_loss: 0.0257
# Epoch 14/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0245 - val_loss: 0.0243
# Epoch 15/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0244 - val_loss: 0.0235
# Epoch 16/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0242 - val_loss: 0.0245
# Epoch 17/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0242 - val_loss: 0.0256
# Epoch 18/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0241 - val_loss: 0.0232
# Epoch 19/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0239 - val_loss: 0.0236
# Epoch 20/100
# 332/332 [==============================] - 4s 14ms/step - loss: 0.0239 - val_loss: 0.0239
# Epoch 21/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0238 - val_loss: 0.0231
# Epoch 22/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0237 - val_loss: 0.0244
# Epoch 23/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0237 - val_loss: 0.0230
# Epoch 24/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0236 - val_loss: 0.0239
# Epoch 25/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0235 - val_loss: 0.0235
# Epoch 26/100
# 332/332 [==============================] - 5s 14ms/step - loss: 0.0235 - val_loss: 0.0228
# Epoch 27/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0234 - val_loss: 0.0232
# Epoch 28/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0234 - val_loss: 0.0229
# Epoch 29/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0233 - val_loss: 0.0230
# Epoch 30/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0232 - val_loss: 0.0238
# Epoch 31/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0232 - val_loss: 0.0239
# Epoch 32/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0231 - val_loss: 0.0232
# Epoch 33/100
# 332/332 [==============================] - 5s 14ms/step - loss: 0.0231 - val_loss: 0.0227
# Epoch 34/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0230 - val_loss: 0.0226
# Epoch 35/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0230 - val_loss: 0.0227
# Epoch 36/100
# 332/332 [==============================] - 5s 14ms/step - loss: 0.0229 - val_loss: 0.0227
# Epoch 37/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0229 - val_loss: 0.0238
# Epoch 38/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0229 - val_loss: 0.0225
# Epoch 39/100
# 332/332 [==============================] - 5s 14ms/step - loss: 0.0228 - val_loss: 0.0227
# Epoch 40/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0227 - val_loss: 0.0226
# Epoch 41/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0227 - val_loss: 0.0229
# Epoch 42/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0227 - val_loss: 0.0228
# Epoch 43/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0226 - val_loss: 0.0224
# Epoch 44/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0226 - val_loss: 0.0226
# Epoch 45/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0226 - val_loss: 0.0223
# Epoch 46/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0225 - val_loss: 0.0228
# Epoch 47/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0225 - val_loss: 0.0230
# Epoch 48/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0225 - val_loss: 0.0225
# Epoch 49/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0224 - val_loss: 0.0221
# Epoch 50/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0225 - val_loss: 0.0225
# Epoch 51/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0225 - val_loss: 0.0226
# Epoch 52/100
# 332/332 [==============================] - 5s 14ms/step - loss: 0.0224 - val_loss: 0.0222
# Epoch 53/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0223 - val_loss: 0.0221
# Epoch 54/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0223 - val_loss: 0.0223
# Epoch 55/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0223 - val_loss: 0.0226
# Epoch 56/100
# 332/332 [==============================] - 5s 14ms/step - loss: 0.0222 - val_loss: 0.0221
# Epoch 57/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0223 - val_loss: 0.0222
# Epoch 58/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0222 - val_loss: 0.0227
# Epoch 59/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0223 - val_loss: 0.0229
# Epoch 60/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0222 - val_loss: 0.0221
# Epoch 61/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0222 - val_loss: 0.0227
# Epoch 62/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0222 - val_loss: 0.0223
# Epoch 63/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0222 - val_loss: 0.0220
# Epoch 64/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0222 - val_loss: 0.0221
# Epoch 65/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0221 - val_loss: 0.0220
# Epoch 66/100
# 332/332 [==============================] - 5s 14ms/step - loss: 0.0221 - val_loss: 0.0229
# Epoch 67/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0221 - val_loss: 0.0219
# Epoch 68/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0221 - val_loss: 0.0221
# Epoch 69/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0221 - val_loss: 0.0220
# Epoch 70/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0220 - val_loss: 0.0219
# Epoch 71/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0220 - val_loss: 0.0219
# Epoch 72/100
# 332/332 [==============================] - 5s 14ms/step - loss: 0.0220 - val_loss: 0.0227
# Epoch 73/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0220 - val_loss: 0.0225
# Epoch 74/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0220 - val_loss: 0.0221
# Epoch 75/100
# 332/332 [==============================] - 5s 14ms/step - loss: 0.0220 - val_loss: 0.0220
# Epoch 76/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0220 - val_loss: 0.0220
# Epoch 77/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0220 - val_loss: 0.0224
# Epoch 78/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0220 - val_loss: 0.0221
# Epoch 79/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0219 - val_loss: 0.0223
# Epoch 80/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0219 - val_loss: 0.0222
# Epoch 81/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0219 - val_loss: 0.0225
# Epoch 82/100
# 332/332 [==============================] - 5s 14ms/step - loss: 0.0219 - val_loss: 0.0228
# Epoch 83/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0219 - val_loss: 0.0219
# Epoch 84/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0219 - val_loss: 0.0218
# Epoch 85/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0219 - val_loss: 0.0219
# Epoch 86/100
# 332/332 [==============================] - 5s 14ms/step - loss: 0.0219 - val_loss: 0.0226
# Epoch 87/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0219 - val_loss: 0.0221
# Epoch 88/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0218 - val_loss: 0.0223
# Epoch 89/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0218 - val_loss: 0.0218
# Epoch 90/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0218 - val_loss: 0.0219
# Epoch 91/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0218 - val_loss: 0.0222
# Epoch 92/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0218 - val_loss: 0.0220
# Epoch 93/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0218 - val_loss: 0.0233
# Epoch 94/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0218 - val_loss: 0.0222
# Epoch 95/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0218 - val_loss: 0.0222
# Epoch 96/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0218 - val_loss: 0.0218
# Epoch 97/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0218 - val_loss: 0.0229
# Epoch 98/100
# 332/332 [==============================] - 4s 13ms/step - loss: 0.0218 - val_loss: 0.0219
# Epoch 99/100
# 332/332 [==============================] - 4s 12ms/step - loss: 0.0218 - val_loss: 0.0217
# Epoch 100/100
# 332/332 [==============================] - 4s 11ms/step - loss: 0.0218 - val_loss: 0.0218
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 32, 32, 64)        640
#
# =================================================================
# Total params: 640 (2.50 KB)
# Trainable params: 640 (2.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# The time of execution of above program is : 415.2314474582672 seconds
