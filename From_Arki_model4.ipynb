# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/binarization-lowres/blob/main/From_Arki_model4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/Architectural_designs/From Arki/"
# Out:
#  313490484_646790150357239_663796780442369775_n.jpg
#  361079911_248325231393045_2145216296096417082_n.jpg
# 'Applied Physics 184 FX-2'
#  Architectural_designs
# 'BS Applied Physics'
#  Classroom
# 'Colab Notebooks'
# 'CONSENT_NARAG_MARK JEREMY_G.pdf'
#  CONSENT_NARAG_MARKJEREMY_G.pdf
# 'Dorm bill.png'
#  fingerprint.pb
# 'Getting started.pdf'
#  IMG_6546.PNG
# 'IMG_9359 (1).PNG'
#  IMG_9359.PNG
# 'Information Sharing Consent Form - NARAG.pdf'
# 'Information Sharing Consent Form.pdf'
# '[Journal of Cultural Heritage] Discovering artistic influences of painters'
# 'MS PHYSICS'
# 'MS Thesis videos'
# 'NARAG, MARK JEREMY, GACIAS.gdoc'
# 'NARAG, MARK JEREMY, GACIAS.pdf'
# 'NARAG, MARK JEREMY.jpg'
#  NIP_Narag_MarkJeremy_Consent.pdf
#  NIP_Narag_MarkJeremy_Informal.jpg
#  NIP_Narag_MarkJeremy_Sablay.jpg
# 'output v1_blue.png'
# 'output v1_gray.png'
# 'output v1_green.png'
# 'output v1_red.png'
# 'output v1_RGB_GRAY.png'
# 'output v1_RGB.png'
# 'output v2_blue.png'
# 'output v2_gray.png'
# 'output v2_green.png'
# 'output v2_red.png'
# 'output v2_RGB_GRAY.png'
# 'output v2_RGB.png'
# 'output v3_blue.png'
# 'output v3_gray.png'
# 'output v3_green.png'
# 'output v3_red.png'
# 'output v3_RGB_GRAY.png'
# 'output v3_RGB.png'
# 'output v4_blue.png'
# 'output v4_gray.png'
# 'output v4_green.png'
# 'output v4_red.png'
# 'output v4_RGB_GRAY.png'
# 'output v4_RGB.png'
# 'output v5_blue.png'
# 'output v5_gray.png'
# 'output v5_green.png'
# 'output v5_red.png'
# 'output v5_RGB_GRAY.png'
# 'output v5_RGB.png'
# 'output v6_blue.png'
# 'output v6_gray.png'
# 'output v6_green.png'
# 'output v6_RGB_GRAY.png'
# 'output v6_RGB.png'
# 'PEHA 2021 Consent Form (fillable).pdf'
# 'PHOTO_NARAG_MARK JEREMY_G.jpg'
#  PHOTO_NARAG_MARKJEREMY_G.jpg
# 'Physics 265'
# 'Physics 301 2S AY2122'
# 'Physics 305 Data Driven Astronomy'
# 'Research files'
#  saved_model.pb
# 'Screen Shot 2022-08-31 at 10.46.42.png'
# 'Screen Shot 2022-09-13 at 12.40.21.png'
# 'Screen Shot 2022-09-13 at 12.43.14.png'
# 'SPP 2022'
# 'Untitled document.gdoc'
# 'Vaccination Card (1).jpg'
# 'Vaccination Card.jpg'
#  variables.data-00000-of-00001

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

epoch = 100
model_number = 4
size = 64

def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.65):
        for i in np.arange(0,int(width/size)+1,0.65):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)


    return data

def crop_(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.65):
        for i in np.arange(0,int(width/size)+1,0.65):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            #im1 = im1/4
            data.append(im1)


    return data



input = np.array(crop_(ImageOps.grayscale(Image.open(file_path + "Rizal_input_wb.png"))))
print("Done reading the input of size = ", input.shape)

output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Rizal_output.png"))))
print("Done reading the output of size = ", input.shape)

train_input = []
test_input = []
for i in range(0,len(input)):
    if i % 4 == 0:
        test_input.append(input[i])
    else:
        train_input.append(input[i])

train_input = np.array(train_input)
test_input = np.array(test_input)

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)

train_output = []
test_output = []
for i in range(0,len(output)):
    if i % 4 == 0:
        test_output.append(output[i])
    else:
        train_output.append(output[i])

train_output = np.array(train_output)
test_output = np.array(test_output)

print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)
# Out:
# Done reading the input of size =  (17160, 64, 64)
# Done reading the output of size =  (17160, 64, 64)
# Done reading the train input of size =  (12870, 64, 64)
# Done reading the test input of size =  (4290, 64, 64)
# Done reading the train output of size =  (12870, 64, 64)
# Done reading the test output of size =  (4290, 64, 64)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((train_input[i+4000]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+4000]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
start = time.time()
import tensorflow as tf

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model

class autoenc(Model):
  def __init__(self):
    super(autoenc, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Input(shape=(size, size, 1)),
      layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=2)])

    self.decoder = tf.keras.Sequential([
      layers.Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = autoenc()


autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

model = autoencoder.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output))

autoencoder.encoder.summary()


autoencoder.save(file_path + '1 Models/' + 'autoencoder_' + str(model_number))

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + '2 Loss/'+'loss_'+ str(model_number) + '.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path + '3 Validation loss/' +'val_loss_'+ str(model_number) + '.csv')

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")
# Out:
# Epoch 1/100
# 403/403 [==============================] - 16s 13ms/step - loss: 0.0401 - val_loss: 0.0259
# Epoch 2/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0262 - val_loss: 0.0235
# Epoch 3/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0243 - val_loss: 0.0231
# Epoch 4/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0230 - val_loss: 0.0212
# Epoch 5/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0221 - val_loss: 0.0199
# Epoch 6/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0207 - val_loss: 0.0188
# Epoch 7/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0199 - val_loss: 0.0182
# Epoch 8/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0194 - val_loss: 0.0179
# Epoch 9/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0190 - val_loss: 0.0176
# Epoch 10/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0187 - val_loss: 0.0174
# Epoch 11/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0185 - val_loss: 0.0183
# Epoch 12/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0183 - val_loss: 0.0171
# Epoch 13/100
# 403/403 [==============================] - 4s 11ms/step - loss: 0.0181 - val_loss: 0.0169
# Epoch 14/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0180 - val_loss: 0.0166
# Epoch 15/100
# 403/403 [==============================] - 5s 14ms/step - loss: 0.0179 - val_loss: 0.0165
# Epoch 16/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0177 - val_loss: 0.0164
# Epoch 17/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0176 - val_loss: 0.0167
# Epoch 18/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0175 - val_loss: 0.0161
# Epoch 19/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0174 - val_loss: 0.0161
# Epoch 20/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0173 - val_loss: 0.0166
# Epoch 21/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0174 - val_loss: 0.0160
# Epoch 22/100
# 403/403 [==============================] - 5s 14ms/step - loss: 0.0172 - val_loss: 0.0160
# Epoch 23/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0172 - val_loss: 0.0159
# Epoch 24/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0171 - val_loss: 0.0159
# Epoch 25/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0171 - val_loss: 0.0158
# Epoch 26/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0171 - val_loss: 0.0158
# Epoch 27/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0170 - val_loss: 0.0160
# Epoch 28/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0170 - val_loss: 0.0157
# Epoch 29/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0169 - val_loss: 0.0158
# Epoch 30/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0169 - val_loss: 0.0157
# Epoch 31/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0169 - val_loss: 0.0157
# Epoch 32/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0169 - val_loss: 0.0156
# Epoch 33/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0168 - val_loss: 0.0158
# Epoch 34/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0168 - val_loss: 0.0156
# Epoch 35/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0168 - val_loss: 0.0156
# Epoch 36/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0168 - val_loss: 0.0160
# Epoch 37/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0167 - val_loss: 0.0158
# Epoch 38/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0167 - val_loss: 0.0155
# Epoch 39/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0167 - val_loss: 0.0155
# Epoch 40/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0167 - val_loss: 0.0156
# Epoch 41/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0167 - val_loss: 0.0155
# Epoch 42/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0166 - val_loss: 0.0154
# Epoch 43/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0166 - val_loss: 0.0154
# Epoch 44/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0166 - val_loss: 0.0155
# Epoch 45/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0166 - val_loss: 0.0155
# Epoch 46/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0166 - val_loss: 0.0155
# Epoch 47/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0166 - val_loss: 0.0153
# Epoch 48/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0165 - val_loss: 0.0153
# Epoch 49/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0165 - val_loss: 0.0154
# Epoch 50/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0165 - val_loss: 0.0155
# Epoch 51/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0165 - val_loss: 0.0165
# Epoch 52/100
# 403/403 [==============================] - 5s 14ms/step - loss: 0.0166 - val_loss: 0.0154
# Epoch 53/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0165 - val_loss: 0.0153
# Epoch 54/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0165 - val_loss: 0.0153
# Epoch 55/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0164 - val_loss: 0.0153
# Epoch 56/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0164 - val_loss: 0.0153
# Epoch 57/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0164 - val_loss: 0.0153
# Epoch 58/100
# 403/403 [==============================] - 5s 14ms/step - loss: 0.0164 - val_loss: 0.0152
# Epoch 59/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0164 - val_loss: 0.0152
# Epoch 60/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0164 - val_loss: 0.0152
# Epoch 61/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0164 - val_loss: 0.0152
# Epoch 62/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0164 - val_loss: 0.0152
# Epoch 63/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0163 - val_loss: 0.0152
# Epoch 64/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0164 - val_loss: 0.0153
# Epoch 65/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0164 - val_loss: 0.0152
# Epoch 66/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0164 - val_loss: 0.0151
# Epoch 67/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0163 - val_loss: 0.0154
# Epoch 68/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0163 - val_loss: 0.0152
# Epoch 69/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0163 - val_loss: 0.0152
# Epoch 70/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0163 - val_loss: 0.0152
# Epoch 71/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0163 - val_loss: 0.0154
# Epoch 72/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0163 - val_loss: 0.0152
# Epoch 73/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0163 - val_loss: 0.0152
# Epoch 74/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0163 - val_loss: 0.0153
# Epoch 75/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0163 - val_loss: 0.0153
# Epoch 76/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0163 - val_loss: 0.0155
# Epoch 77/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0163 - val_loss: 0.0153
# Epoch 78/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0163 - val_loss: 0.0151
# Epoch 79/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0162 - val_loss: 0.0151
# Epoch 80/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0163 - val_loss: 0.0151
# Epoch 81/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0162 - val_loss: 0.0151
# Epoch 82/100
# 403/403 [==============================] - 5s 11ms/step - loss: 0.0162 - val_loss: 0.0151
# Epoch 83/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0162 - val_loss: 0.0153
# Epoch 84/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0162 - val_loss: 0.0151
# Epoch 85/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0162 - val_loss: 0.0151
# Epoch 86/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0162 - val_loss: 0.0151
# Epoch 87/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0162 - val_loss: 0.0153
# Epoch 88/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0162 - val_loss: 0.0151
# Epoch 89/100
# 403/403 [==============================] - 5s 14ms/step - loss: 0.0162 - val_loss: 0.0152
# Epoch 90/100
# 403/403 [==============================] - 6s 14ms/step - loss: 0.0162 - val_loss: 0.0155
# Epoch 91/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0161 - val_loss: 0.0153
# Epoch 92/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0162 - val_loss: 0.0151
# Epoch 93/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0161 - val_loss: 0.0153
# Epoch 94/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0161 - val_loss: 0.0150
# Epoch 95/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0162 - val_loss: 0.0151
# Epoch 96/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0161 - val_loss: 0.0150
# Epoch 97/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0161 - val_loss: 0.0150
# Epoch 98/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0161 - val_loss: 0.0150
# Epoch 99/100
# 403/403 [==============================] - 5s 13ms/step - loss: 0.0161 - val_loss: 0.0151
# Epoch 100/100
# 403/403 [==============================] - 5s 12ms/step - loss: 0.0161 - val_loss: 0.0150
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 64)        640
#
# =================================================================
# Total params: 640 (2.50 KB)
# Trainable params: 640 (2.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# The time of execution of above program is : 568.566656589508 seconds
