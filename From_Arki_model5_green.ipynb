# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/binarization-lowres/blob/main/From_Arki_model5_green.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/Architectural_designs/From Arki/"
# Out:
#  313490484_646790150357239_663796780442369775_n.jpg
#  361079911_248325231393045_2145216296096417082_n.jpg
# 'Applied Physics 184 FX-2'
#  Architectural_designs
# 'BS Applied Physics'
#  Classroom
# 'Colab Notebooks'
# 'CONSENT_NARAG_MARK JEREMY_G.pdf'
#  CONSENT_NARAG_MARKJEREMY_G.pdf
# 'Dorm bill.png'
# 'Getting started.pdf'
#  IMG_6546.PNG
# 'IMG_9359 (1).PNG'
#  IMG_9359.PNG
# 'Information Sharing Consent Form - NARAG.pdf'
# 'Information Sharing Consent Form.pdf'
# '[Journal of Cultural Heritage] Discovering artistic influences of painters'
# 'MS PHYSICS'
# 'MS Thesis videos'
# 'NARAG, MARK JEREMY, GACIAS.gdoc'
# 'NARAG, MARK JEREMY, GACIAS.pdf'
# 'NARAG, MARK JEREMY.jpg'
#  NIP_Narag_MarkJeremy_Consent.pdf
#  NIP_Narag_MarkJeremy_Informal.jpg
#  NIP_Narag_MarkJeremy_Sablay.jpg
# 'PEHA 2021 Consent Form (fillable).pdf'
# 'PHOTO_NARAG_MARK JEREMY_G.jpg'
#  PHOTO_NARAG_MARKJEREMY_G.jpg
# 'Physics 265'
# 'Physics 301 2S AY2122'
# 'Physics 305 Data Driven Astronomy'
# 'Research files'
# 'Screen Shot 2022-08-31 at 10.46.42.png'
# 'Screen Shot 2022-09-13 at 12.40.21.png'
# 'Screen Shot 2022-09-13 at 12.43.14.png'
# 'SPP 2022'
# 'Untitled document.gdoc'
# 'Vaccination Card (1).jpg'
# 'Vaccination Card.jpg'

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

epoch = 100
model_number = 5
size = 128

def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.33):
        for i in np.arange(0,int(width/size)+1,0.33):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)


    return data

def crop_(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.33):
        for i in np.arange(0,int(width/size)+1,0.33):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            #im1 = im1/4
            data.append(im1)


    return data



input = np.array(crop_(ImageOps.grayscale(Image.open(file_path + "green_Rizal_input.png"))))
print("Done reading the input of size = ", input.shape)

output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Rizal_output.png"))))
print("Done reading the output of size = ", input.shape)

train_input = []
test_input = []
for i in range(0,len(input)):
    if i % 4 == 0:
        test_input.append(input[i])
    else:
        train_input.append(input[i])

train_input = np.array(train_input)
test_input = np.array(test_input)

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)

train_output = []
test_output = []
for i in range(0,len(output)):
    if i % 4 == 0:
        test_output.append(output[i])
    else:
        train_output.append(output[i])

train_output = np.array(train_output)
test_output = np.array(test_output)

print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)
# Out:
# Done reading the input of size =  (17050, 128, 128)
# Done reading the output of size =  (17050, 128, 128)
# Done reading the train input of size =  (12787, 128, 128)
# Done reading the test input of size =  (4263, 128, 128)
# Done reading the train output of size =  (12787, 128, 128)
# Done reading the test output of size =  (4263, 128, 128)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((test_input[i+1000]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((test_output[i+1000]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
start = time.time()
import tensorflow as tf

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model

class autoenc(Model):
  def __init__(self):
    super(autoenc, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Input(shape=(size, size, 1)),
      layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=2),
      layers.Conv2D(128, (3, 3), activation='relu', padding='same', strides=2),
      layers.Conv2D(256, (3, 3), activation='relu', padding='same', strides=2)])

    self.decoder = tf.keras.Sequential([
      layers.Conv2DTranspose(256, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2DTranspose(128, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = autoenc()


autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

model = autoencoder.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output))

autoencoder.encoder.summary()


autoencoder.save(file_path + '1 Models/' + 'autoencoder_' + str(model_number)+'_green')

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + '2 Loss/'+'loss_'+ str(model_number) + '_green.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path + '3 Validation loss/' +'val_loss_'+ str(model_number) + '_green.csv')

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")
# Out:
# Epoch 1/100
# 400/400 [==============================] - 54s 101ms/step - loss: 0.0711 - val_loss: 0.0550
# Epoch 2/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0451 - val_loss: 0.0277
# Epoch 3/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0235 - val_loss: 0.0207
# Epoch 4/100
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0197 - val_loss: 0.0199
# Epoch 5/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0178 - val_loss: 0.0169
# Epoch 6/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0166 - val_loss: 0.0161
# Epoch 7/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0162 - val_loss: 0.0159
# Epoch 8/100
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0157 - val_loss: 0.0154
# Epoch 9/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0154 - val_loss: 0.0153
# Epoch 10/100
# 400/400 [==============================] - 39s 99ms/step - loss: 0.0151 - val_loss: 0.0150
# Epoch 11/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0149 - val_loss: 0.0149
# Epoch 12/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0148 - val_loss: 0.0146
# Epoch 13/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0147 - val_loss: 0.0145
# Epoch 14/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0145 - val_loss: 0.0145
# Epoch 15/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0144 - val_loss: 0.0144
# Epoch 16/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0143 - val_loss: 0.0144
# Epoch 17/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0142 - val_loss: 0.0142
# Epoch 18/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0141 - val_loss: 0.0141
# Epoch 19/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0139 - val_loss: 0.0142
# Epoch 20/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0139 - val_loss: 0.0138
# Epoch 21/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0137 - val_loss: 0.0138
# Epoch 22/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0137 - val_loss: 0.0137
# Epoch 23/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0136 - val_loss: 0.0137
# Epoch 24/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0135 - val_loss: 0.0136
# Epoch 25/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0139 - val_loss: 0.0137
# Epoch 26/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0134 - val_loss: 0.0135
# Epoch 27/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0132 - val_loss: 0.0136
# Epoch 28/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0132 - val_loss: 0.0136
# Epoch 29/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0131 - val_loss: 0.0134
# Epoch 30/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0130 - val_loss: 0.0134
# Epoch 31/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0129 - val_loss: 0.0133
# Epoch 32/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0129 - val_loss: 0.0133
# Epoch 33/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0128 - val_loss: 0.0134
# Epoch 34/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0128 - val_loss: 0.0132
# Epoch 35/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0127 - val_loss: 0.0133
# Epoch 36/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0126 - val_loss: 0.0131
# Epoch 37/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0125 - val_loss: 0.0132
# Epoch 38/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0125 - val_loss: 0.0131
# Epoch 39/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0124 - val_loss: 0.0130
# Epoch 40/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0124 - val_loss: 0.0130
# Epoch 41/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0123 - val_loss: 0.0132
# Epoch 42/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0122 - val_loss: 0.0129
# Epoch 43/100
# 400/400 [==============================] - 39s 97ms/step - loss: 0.0121 - val_loss: 0.0129
# Epoch 44/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0121 - val_loss: 0.0129
# Epoch 45/100
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0120 - val_loss: 0.0131
# Epoch 46/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0119 - val_loss: 0.0130
# Epoch 47/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0119 - val_loss: 0.0129
# Epoch 48/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0118 - val_loss: 0.0129
# Epoch 49/100
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0118 - val_loss: 0.0129
# Epoch 50/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0117 - val_loss: 0.0130
# Epoch 51/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0116 - val_loss: 0.0129
# Epoch 52/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0116 - val_loss: 0.0129
# Epoch 53/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0115 - val_loss: 0.0128
# Epoch 54/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0114 - val_loss: 0.0129
# Epoch 55/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0114 - val_loss: 0.0128
# Epoch 56/100
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0113 - val_loss: 0.0128
# Epoch 57/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0112 - val_loss: 0.0128
# Epoch 58/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0112 - val_loss: 0.0129
# Epoch 59/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0112 - val_loss: 0.0128
# Epoch 60/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0111 - val_loss: 0.0129
# Epoch 61/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0110 - val_loss: 0.0129
# Epoch 62/100
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0110 - val_loss: 0.0128
# Epoch 63/100
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0109 - val_loss: 0.0132
# Epoch 64/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0108 - val_loss: 0.0130
# Epoch 65/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0108 - val_loss: 0.0129
# Epoch 66/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0107 - val_loss: 0.0130
# Epoch 67/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0107 - val_loss: 0.0129
# Epoch 68/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0106 - val_loss: 0.0129
# Epoch 69/100
# 400/400 [==============================] - 39s 97ms/step - loss: 0.0106 - val_loss: 0.0129
# Epoch 70/100
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0105 - val_loss: 0.0129
# Epoch 71/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0104 - val_loss: 0.0129
# Epoch 72/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0104 - val_loss: 0.0130
# Epoch 73/100
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0104 - val_loss: 0.0130
# Epoch 74/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0103 - val_loss: 0.0131
# Epoch 75/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0103 - val_loss: 0.0129
# Epoch 76/100
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0102 - val_loss: 0.0130
# Epoch 77/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0102 - val_loss: 0.0129
# Epoch 78/100
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0101 - val_loss: 0.0130
# Epoch 79/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0101 - val_loss: 0.0130
# Epoch 80/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0100 - val_loss: 0.0130
# Epoch 81/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0100 - val_loss: 0.0130
# Epoch 82/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0099 - val_loss: 0.0133
# Epoch 83/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0099 - val_loss: 0.0131
# Epoch 84/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0098 - val_loss: 0.0131
# Epoch 85/100
# 400/400 [==============================] - 39s 97ms/step - loss: 0.0098 - val_loss: 0.0131
# Epoch 86/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0097 - val_loss: 0.0131
# Epoch 87/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0097 - val_loss: 0.0131
# Epoch 88/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0097 - val_loss: 0.0131
# Epoch 89/100
# 400/400 [==============================] - 39s 97ms/step - loss: 0.0096 - val_loss: 0.0131
# Epoch 90/100
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0096 - val_loss: 0.0132
# Epoch 91/100
# 400/400 [==============================] - 39s 97ms/step - loss: 0.0096 - val_loss: 0.0132
# Epoch 92/100
# 400/400 [==============================] - 40s 100ms/step - loss: 0.0095 - val_loss: 0.0131
# Epoch 93/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0095 - val_loss: 0.0132
# Epoch 94/100
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0094 - val_loss: 0.0132
# Epoch 95/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0094 - val_loss: 0.0132
# Epoch 96/100
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0094 - val_loss: 0.0133
# Epoch 97/100
# 400/400 [==============================] - 39s 97ms/step - loss: 0.0093 - val_loss: 0.0133
# Epoch 98/100
# 400/400 [==============================] - 39s 98ms/step - loss: 0.0093 - val_loss: 0.0132
# Epoch 99/100
# 400/400 [==============================] - 39s 97ms/step - loss: 0.0092 - val_loss: 0.0133
# Epoch 100/100
# 400/400 [==============================] - 40s 99ms/step - loss: 0.0092 - val_loss: 0.0134
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       73856
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)       295168
#
# =================================================================
# Total params: 369664 (1.41 MB)
# Trainable params: 369664 (1.41 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# The time of execution of above program is : 3992.3311553001404 seconds
