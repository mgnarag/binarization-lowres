# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/binarization-lowres/blob/main/From_Arki_model6_green.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/Architectural_designs/From Arki/"
# Out:
# '20200904_105320[1].jpg'
# '5th Year 1st Sem 1st VIP Progress Report.pdf'
# '5th Year 1st Sem 1st VIP Progress Report.pptx'
#  6050_XXXXXX5284_HO01190614_20210628.zip
#  7008837749.zip
# 'A0042 ICMIP.gslides'
# 'AP 165 Camera Obscura.gdoc'
# 'AP 183 LE1'
#  Architectural_designs
# 'Art and Science - STS Final Report.gdoc'
#  autoencoder_6_red_200
#  BPI-PHILAM-XXXXXX5284.zip
#  Classroom
# 'Colab Notebooks'
# 'Continuous RV Probability Distributions (Annotated).pptx'
# 'Copy of Addition of Vectors.pdf'
# 'Copy of Buoyancy.pdf'
# 'Copy of Free Fall.pdf'
# 'Copy of Measurement, Uncertainty, and Deviation.pdf'
# 'Copy of Measuring Devices.pdf'
# 'Copy of Physical Pendulum.pdf'
# 'Copy of Projectile Motion.pdf'
# 'Copy of Rotation.pdf'
# 'Copy of Sound.pdf'
# 'Copy of Torque and Equilibrium.pdf'
# 'Curriculum Vitae.pdf'
# 'CWTS Accomplishment Report.gdoc'
#  docslide.us_david-j-griffiths-instructors-solution-manuals-to-introduction-to-electrodynamics.pdf
#  DSC_2913.JPG
#  DSC_2914.JPG
#  DSC_2919.JPG
#  DSC_2920.JPG
#  DSC_2921.JPG
#  DSC_2924.JPG
#  DSC_3059.JPG
#  DSC_3060.JPG
#  dyadry.gdoc
# 'DYAD Skit.gdoc'
# 'Eugene Hecht-Optics-Addison-Wesley (2002) (1).pdf'
# 'Eugene Hecht-Optics-Addison-Wesley (2002).pdf'
# 'Experiment 1 AP185.gdoc'
# 'FINAL THESIS DEFENSE SLIDES.pptx'
#  Flowchart.gslides
#  Flowchart.pptx
# 'Gantt Chart - NIP CWTS Group 3.gsheet'
# 'Geog 1 Conversion.gsheet'
# 'Geog 1.gsheet'
# 'GEOL 11.gdoc'
# 'Getting started.pdf'
# 'Group Discussion | Team ChocNut.gslides'
#  Home
# 'Kamia girls barkada'
# 'Kape o USC.gform'
# 'LAMBAK DP'
# 'Letter for late payment.gdoc'
#  Malaysia.pptx
# 'Mount Pulag July 9-10'
# 'NARAG_Curriculum Vitae.pdf'
# 'NARAG_Letter of Motivation.pdf'
# 'narag_markjeremy_journalpaperreport[1].gdoc'
# 'NARAG_Proposal (1).pdf'
# 'NARAG_Proposal (2).pdf'
# 'NARAG_Proposal (3).pdf'
#  NARAG_Proposal.pdf
# 'NIP COVID 19 Report.gsheet'
#  OAR_NARAG
# '[Paul_Horowitz,_Winfield_Hill]_The_Art_of_Electron(BookZZ.org).pdf'
# 'Physics 104.1 Slideshow Presentation.gslides'
# 'Physics 192 Presentation.gslides'
# 'Physics 71 Orye Slides.gslides'
# 'Physics 72.1 Zoom recording'
# 'PI 100 Project'
# 'Pic (1).zip'
#  Pic.zip
# 'Pubwave 3.pptx'
# 'request for late payment JF 1st sem AY 2020-2021.gdoc'
# 'Research Meeting 6 (March 6).pptx'
# 'Research Meeting 6 (March 6).pptx.gslides'
# 'Science fair.gslides'
# 'Science project.gslides'
# 'SPP 2022'
# 'Spring Mass.py'
# 'stellarium-0.17.0-win64(1).exe'
# 'STS: Arts and Science.gdoc'
# 'STS Group 14 Travel Time.gsheet'
# 'Survey on how do you want your physics instructors to handle the class.gform'
# 'Tarp Designs.zip'
#  tARP.pptx
# 'Thesis slides - Finals.pptx'
# 'Thesis slides - Finals.zip'
# 'Thesis slides.gslides'
# 'Thesis slides.pptx'
# 'Untitled document.gdoc'
# "UP Lambak Applicants' Orientation.gform"
# 'VIP Graduates 2017'
# 'VIP ML Lec#1.gslides'
# 'VIP ML Lecture #2.gslides'
# 'VIP ML Lecture #3.gslides'
# 'VIP ML Lecture #4.gslides'
# 'VIP Seminar Schedule 1st Sem AY 2020-2021.gsheet'
# 'Water clear LEDs (1).jpg'
# 'Water clear LEDs.jpg'
#  WIN_20200904_10_46_52_Pro.jpg
# 'Zambales - March 2022'

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

epoch = 100
model_number = 6
size = 128

def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.33):
        for i in np.arange(0,int(width/size)+1,0.33):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)


    return data

def crop_(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.33):
        for i in np.arange(0,int(width/size)+1,0.33):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            #im1 = im1/4
            data.append(im1)


    return data



input = np.array(crop_(ImageOps.grayscale(Image.open(file_path + "green_Rizal_input_wb.png"))))
print("Done reading the input of size = ", input.shape)

output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Rizal_output.png"))))
print("Done reading the output of size = ", input.shape)

train_input = []
test_input = []
for i in range(0,len(input)):
    if i % 4 == 0:
        test_input.append(input[i])
    else:
        train_input.append(input[i])

train_input = np.array(train_input)
test_input = np.array(test_input)

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)

train_output = []
test_output = []
for i in range(0,len(output)):
    if i % 4 == 0:
        test_output.append(output[i])
    else:
        train_output.append(output[i])

train_output = np.array(train_output)
test_output = np.array(test_output)

print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)
# Out:
# Done reading the input of size =  (17050, 128, 128)
# Done reading the output of size =  (17050, 128, 128)
# Done reading the train input of size =  (12787, 128, 128)
# Done reading the test input of size =  (4263, 128, 128)
# Done reading the train output of size =  (12787, 128, 128)
# Done reading the test output of size =  (4263, 128, 128)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((train_input[i+6000]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+6000]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
start = time.time()
import tensorflow as tf

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model



class autoenc(Model):
  def __init__(self):
    super(autoenc, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Input(shape=(size, size, 1)),
      layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=2)])

    self.decoder = tf.keras.Sequential([
      layers.Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = autoenc()


autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

model = autoencoder.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output))

autoencoder.encoder.summary()


autoencoder.save(file_path + '1 Models/' + 'autoencoder_' + str(model_number)+'_green')

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + '2 Loss/'+'loss_'+ str(model_number) + '_green.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path + '3 Validation loss/' +'val_loss_'+ str(model_number) + '_green.csv')

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")
# Out:
# Epoch 1/100
# 400/400 [==============================] - 29s 43ms/step - loss: 0.0399 - val_loss: 0.0270
# Epoch 2/100
# 400/400 [==============================] - 15s 37ms/step - loss: 0.0242 - val_loss: 0.0224
# Epoch 3/100
# 400/400 [==============================] - 15s 38ms/step - loss: 0.0219 - val_loss: 0.0217
# Epoch 4/100
# 400/400 [==============================] - 15s 38ms/step - loss: 0.0205 - val_loss: 0.0196
# Epoch 5/100
# 400/400 [==============================] - 15s 38ms/step - loss: 0.0193 - val_loss: 0.0187
# Epoch 6/100
# 400/400 [==============================] - 15s 38ms/step - loss: 0.0187 - val_loss: 0.0183
# Epoch 7/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0182 - val_loss: 0.0180
# Epoch 8/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0180 - val_loss: 0.0177
# Epoch 9/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0177 - val_loss: 0.0176
# Epoch 10/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0175 - val_loss: 0.0174
# Epoch 11/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0173 - val_loss: 0.0171
# Epoch 12/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0172 - val_loss: 0.0173
# Epoch 13/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0171 - val_loss: 0.0168
# Epoch 14/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0170 - val_loss: 0.0168
# Epoch 15/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0169 - val_loss: 0.0166
# Epoch 16/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0167 - val_loss: 0.0166
# Epoch 17/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0166 - val_loss: 0.0164
# Epoch 18/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0166 - val_loss: 0.0165
# Epoch 19/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0165 - val_loss: 0.0165
# Epoch 20/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0164 - val_loss: 0.0163
# Epoch 21/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0163 - val_loss: 0.0162
# Epoch 22/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0163 - val_loss: 0.0165
# Epoch 23/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0162 - val_loss: 0.0161
# Epoch 24/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0162 - val_loss: 0.0161
# Epoch 25/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0161 - val_loss: 0.0161
# Epoch 26/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0161 - val_loss: 0.0160
# Epoch 27/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0161 - val_loss: 0.0162
# Epoch 28/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0161 - val_loss: 0.0159
# Epoch 29/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0160 - val_loss: 0.0159
# Epoch 30/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0160 - val_loss: 0.0162
# Epoch 31/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0159 - val_loss: 0.0160
# Epoch 32/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0159 - val_loss: 0.0159
# Epoch 33/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0159 - val_loss: 0.0159
# Epoch 34/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0159 - val_loss: 0.0160
# Epoch 35/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0159 - val_loss: 0.0158
# Epoch 36/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0158 - val_loss: 0.0158
# Epoch 37/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0158 - val_loss: 0.0158
# Epoch 38/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0158 - val_loss: 0.0157
# Epoch 39/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0158 - val_loss: 0.0157
# Epoch 40/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0158 - val_loss: 0.0157
# Epoch 41/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0158 - val_loss: 0.0157
# Epoch 42/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0157 - val_loss: 0.0157
# Epoch 43/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0158 - val_loss: 0.0156
# Epoch 44/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0157 - val_loss: 0.0157
# Epoch 45/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0157 - val_loss: 0.0158
# Epoch 46/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0157 - val_loss: 0.0156
# Epoch 47/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0157 - val_loss: 0.0156
# Epoch 48/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0156 - val_loss: 0.0156
# Epoch 49/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0156 - val_loss: 0.0155
# Epoch 50/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0156 - val_loss: 0.0157
# Epoch 51/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0156 - val_loss: 0.0155
# Epoch 52/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0156 - val_loss: 0.0155
# Epoch 53/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0156 - val_loss: 0.0154
# Epoch 54/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0156 - val_loss: 0.0155
# Epoch 55/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0156 - val_loss: 0.0155
# Epoch 56/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0155 - val_loss: 0.0154
# Epoch 57/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0155 - val_loss: 0.0155
# Epoch 58/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0155 - val_loss: 0.0154
# Epoch 59/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0155 - val_loss: 0.0154
# Epoch 60/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0155 - val_loss: 0.0154
# Epoch 61/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0155 - val_loss: 0.0156
# Epoch 62/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0155 - val_loss: 0.0154
# Epoch 63/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0155 - val_loss: 0.0154
# Epoch 64/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0155 - val_loss: 0.0154
# Epoch 65/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0154 - val_loss: 0.0154
# Epoch 66/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0154 - val_loss: 0.0154
# Epoch 67/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0154 - val_loss: 0.0154
# Epoch 68/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0154 - val_loss: 0.0154
# Epoch 69/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0154 - val_loss: 0.0156
# Epoch 70/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0154 - val_loss: 0.0153
# Epoch 71/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0154 - val_loss: 0.0154
# Epoch 72/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0154 - val_loss: 0.0153
# Epoch 73/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0154 - val_loss: 0.0157
# Epoch 74/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0154 - val_loss: 0.0152
# Epoch 75/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0154 - val_loss: 0.0153
# Epoch 76/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0154 - val_loss: 0.0153
# Epoch 77/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0153 - val_loss: 0.0153
# Epoch 78/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0153 - val_loss: 0.0152
# Epoch 79/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0153 - val_loss: 0.0153
# Epoch 80/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0153 - val_loss: 0.0152
# Epoch 81/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0153 - val_loss: 0.0153
# Epoch 82/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0153 - val_loss: 0.0153
# Epoch 83/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0153 - val_loss: 0.0153
# Epoch 84/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0153 - val_loss: 0.0156
# Epoch 85/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0153 - val_loss: 0.0153
# Epoch 86/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0153 - val_loss: 0.0152
# Epoch 87/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0153 - val_loss: 0.0153
# Epoch 88/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0153 - val_loss: 0.0153
# Epoch 89/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0153 - val_loss: 0.0153
# Epoch 90/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0153 - val_loss: 0.0152
# Epoch 91/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0153 - val_loss: 0.0153
# Epoch 92/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0153 - val_loss: 0.0152
# Epoch 93/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0153 - val_loss: 0.0152
# Epoch 94/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0152 - val_loss: 0.0152
# Epoch 95/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0153 - val_loss: 0.0151
# Epoch 96/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0152 - val_loss: 0.0152
# Epoch 97/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0152 - val_loss: 0.0152
# Epoch 98/100
# 400/400 [==============================] - 16s 39ms/step - loss: 0.0152 - val_loss: 0.0152
# Epoch 99/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0152 - val_loss: 0.0152
# Epoch 100/100
# 400/400 [==============================] - 16s 40ms/step - loss: 0.0152 - val_loss: 0.0151
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 64)        640
#
# =================================================================
# Total params: 640 (2.50 KB)
# Trainable params: 640 (2.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# The time of execution of above program is : 1651.3710072040558 seconds
