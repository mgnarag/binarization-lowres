# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/binarization-lowres/blob/main/From_Arki_model1_blue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/Architectural_designs/From Arki/"
# Out:
# '107.1 syllabus 1SAY1920 FINAL.gdoc'
# '1C-01 Narag et al (1).pdf'
# '1C-01 Narag et al.pdf'
# '1FA971504AC646559D05A8ED6341AFB3[1025340].png'
# '1H-04 Narag et al.pdf'
#  20220802_182749.heic
#  20220802_182831.heic
#  20220802_183259.heic
#  20220803_125819.heic
#  20220803_125842.heic
#  20220803_144229.heic
#  20220803_144422.heic
#  20220803_160724.heic
#  20220803_160751.heic
#  20220803_165240.heic
#  20220803_165318.heic
#  20220803_174701.heic
#  20220803_174706.heic
#  20220804_175217.heic
#  20220804_175443.heic
#  20220804_175616.heic
#  20220804_181917.heic
#  20220804_182007.heic
#  20220804_182117.heic
#  2S22-23_LE3-Regular-Set-A-FINAL-KEY.pdf
# 'A4_Physics 71 TWHFU-3_gradesheet (1).pdf'
# 'A4_Physics 71 TWHFU-3_officialgrades (1).pdf'
# 'A4_Physics 71 TWHFU-3_officialgrades.gdoc'
# 'Abstract - NARAG, Mark Jeremy.pdf'
# 'Annex 1 (copy of Journal).pdf'
# 'Annex 2 (Proof of employments).pdf'
# 'App Physics 181 THY-FX-2_studentcontactlist.xlsx'
#  Architectural_designs
# 'Binarizing architectural drawings'
#  Classroom
# 'Colab Notebooks'
# 'Color Difference Specification 2016.pptx'
#  CS_NIP_201819_S2_BS_AppliedPhysics_Narag_Mark_Jeremy.pdf
#  D54dUVpU8AIZzoD.jpeg
#  Data.tex
# 'Dormitory Stay Request MNarag.docx.pdf'
#  DrzPc0sUwAAyQHi.jpeg
#  DvO96koV4AAD6PP.jpeg
# 'DvO976tVAAEQ9ym (1).jpeg'
#  DvO976tVAAEQ9ym.jpeg
# 'Employment Survey.gdoc'
# 'FBC-2_Banez (1).pdf'
#  FBC-2_Banez.pdf
#  FdUaD2nUcAAki1b.jpeg
# 'Figure 1.png'
# 'Figure 2.png'
# 'fingerprint (1).pb'
# 'fingerprint (2).pb'
# 'fingerprint (3).pb'
# 'fingerprint (4).pb'
#  fingerprint.pb
# 'Form5a and Grades.zip'
#  Fringes.zip
#  FSR_120201_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120202_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120212_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
#  FSR_120221_NARAG_MARK_JEREMY_GACIAS_NIP.pdf
# 'Getting started.pdf'
#  IMG_5634.JPG
#  IMG_6572.jpeg
#  IMG_6578.jpeg
# 'IMG_6587 (1).jpeg'
#  IMG_6587.jpeg
#  IPA-Form4.1-2021Rev072021-1.pdf
#  IPA-Form4.2-2021Rev072021.docx
#  IPA-Form4.3-2021Rev072021.pdf
# 'item sample.tex'
# 'item template.tex'
# 'Jas Jem utang.gsheet'
# 'JFR Reduced Fees for 1st Sem AY 20-21.zip'
# 'Lecture 22 - Torque.pptx'
# 'Lecture 23 - Dynamics of Rotation.pptx'
# 'Lecture 24 - Angular Momentum.pptx'
# 'Lecture 25 - Equilibrium and Center of Gravity.pptx'
# 'Lecture 26 - Density and Pressure in a Fluid.pptx'
# 'Lecture 27 - Buoyancy.pptx'
# 'LRM_20220804_195432 (1).dng'
#  LRM_20220804_195432.dng
#  LRM_20220804_195500.dng
#  LRM_20220804_195546.dng
#  LRM_20220805_113837.dng
#  LRM_20220805_142837.dng
#  LRM_20220805_143054.dng
#  LRM_20220805_143817.dng
# 'MALIPOL_CHAE ANN.pdf'
#  Metric_100dpi.csv
#  Metric_500.csv
# 'NARAG_MARKJEREMY (1).BC.pdf'
#  NARAG_MARKJEREMY.BC.pdf
#  NARAG_MARKJEREMY.CC.png
#  NARAG_MARKJEREMY.dcog.pdf
#  NARAG_MARKJEREMY.DC.pdf
#  NARAG_MARKJEREMY.FL.pdf
#  NARAG_MARKJEREMY.Form1.1.pdf
#  NARAG_MARKJEREMY.POS.pdf
#  NARAG_MARKJEREMY.SD.pdf
#  NARAG_MARKJEREMY.TCGTOR.pdf
# '[NARAG] Physics 242 Final Report.pdf'
# '[NARAG] Physics 242 PS 1.pdf'
# '[NARAG] Physics 242 PS 2.pdf'
# 'Narag SPP Cert.pdf'
#  NARAG_Travel-Report-Form-2019.pdf
# 'NIP COVID-19 Case Report Form.gform'
# 'NIP COVID-19 Case Report Form (Responses).gsheet'
# 'NIP COVID19 Report.gsheet'
# 'NIP Year End Party 2022'
#  NRAG_MARKJEREMY.OTRTCG.pdf
# 'Optics in Art and Art Analysis (1).pptx'
# 'Optics in Art and Art Analysis.pptx'
# 'OUR CErtificate.gdoc'
# 'OUR CErtificate.pdf'
# 'output v1_100dpi.png'
# 'output v2_100dpi.png'
# 'output v3_100dpi.png'
# 'output v3_500.png'
# 'output v4_100dpi.png'
# 'output v5_100dpi.png'
# 'output v6_100dpi.png'
# 'OVCRD IPA Reference Slip (2021-0929-1691-5873).pdf'
# 'PA-08 Narag et al.pdf'
#  PA-08.pdf
# 'Parallel Presentation.gslides'
# 'PEER EVALUTION - Physics 72.1 HBC-1 .gform'
# 'PEER EVALUTION - Physics 72.1 TDE-1 .gform'
# 'PEER EVALUTION - Physics 72.1 WDE-1 .gform'
# 'Physics 107.1 MBCD-2_studentcontactlist.xlsx'
#  Physics305_plasma
# 'Physics 71.1 WIJ FIJ and 72.1 TBC.gsheet'
#  Physics_71_Syllabus.zip
# 'Physics_71_Syllabus.zip (Unzipped Files)'
# '[Physics 71 V-2] Attendance.gsheet'
# 'Physics 72.1 2nd Sem AY 2019-2020.gsheet'
# 'Rene Jem utang.gsheet'
# 'Research files'
# 'Sablay picture.jpeg'
# 'saved_model (1).pb'
# 'saved_model (2).pb'
# 'saved_model (3).pb'
# 'saved_model (4).pb'
#  saved_model.pb
# 'Screenshot 2023-02-12 at 12.13.51 (1).png'
# 'Screenshot 2023-02-12 at 12.13.51.png'
# 'Screenshot 2023-06-29 at 19.20.04.png'
# 'Screenshot 2023-06-29 at 19.26.09.png'
#  Smokers.mp4
# 'SORRY SIR HUHU.gdoc'
# 'SORRY SIR HUHU.pdf'
# 'SPP-2023-1H-04 (1).pptx'
#  SPP-2023-1H-04.pptx
#  SPP_2023-Contributed-26.pdf
# 'SPP-2023-PB-05  .pdf'
#  SPP_Appearance-45.pdf
# 'SPP Cert of Appearance NARAG (1).pdf'
# 'SPP Cert of Appearance NARAG (2).pdf'
# 'SPP Cert of Appearance NARAG.pdf'
# 'Testing on DIV2K dataset.pdf'
# '[THY-FX] Physics 181 LE1 Submissions 2nd Sem AY 2020-21'
#  Travel-Report-Form-2019.pdf
# 'Undergraduate Research'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'variables (1).data-00000-of-00001'
# 'variables (2).data-00000-of-00001'
# 'variables (3).data-00000-of-00001'
# 'variables (4).data-00000-of-00001'
#  variables.data-00000-of-00001
# 'Waiver for more than 18 units [2nd sem AY 20-21].gdoc'

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

epoch = 100
model_number = 1
size = 32

def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,1.3):
        for i in np.arange(0,int(width/size)+1,1.3):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)


    return data

def crop_(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,1.3):
        for i in np.arange(0,int(width/size)+1,1.3):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            #im1 = im1/4
            data.append(im1)


    return data



input = np.array(crop_(ImageOps.grayscale(Image.open(file_path + "blue_Rizal_input_wb.png"))))
print("Done reading the input of size = ", input.shape)

output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Rizal_output.png"))))
print("Done reading the output of size = ", input.shape)

train_input = []
test_input = []
for i in range(0,len(input)):
    if i % 4 == 0:
        test_input.append(input[i])
    else:
        train_input.append(input[i])

train_input = np.array(train_input)
test_input = np.array(test_input)

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)

train_output = []
test_output = []
for i in range(0,len(output)):
    if i % 4 == 0:
        test_output.append(output[i])
    else:
        train_output.append(output[i])

train_output = np.array(train_output)
test_output = np.array(test_output)

print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)
# Out:
# Done reading the input of size =  (16895, 32, 32)
# Done reading the output of size =  (16895, 32, 32)
# Done reading the train input of size =  (12671, 32, 32)
# Done reading the test input of size =  (4224, 32, 32)
# Done reading the train output of size =  (12671, 32, 32)
# Done reading the test output of size =  (4224, 32, 32)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((train_input[i+7000]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+7000]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
start = time.time()
import tensorflow as tf

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model

class autoenc(Model):
  def __init__(self):
    super(autoenc, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Input(shape=(size, size, 1)),
      layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=2),
      layers.Conv2D(128, (3, 3), activation='relu', padding='same', strides=2)])

    self.decoder = tf.keras.Sequential([
      layers.Conv2DTranspose(128, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = autoenc()


autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

model = autoencoder.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output))

autoencoder.encoder.summary()


autoencoder.save(file_path + '1 Models/' + 'autoencoder_' + str(model_number)+'_blue')

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + '2 Loss/'+'loss_'+ str(model_number) + '_blue.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path + '3 Validation loss/' +'val_loss_'+ str(model_number) + '_blue.csv')

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")
# Out:
# Epoch 1/100
# 396/396 [==============================] - 16s 9ms/step - loss: 0.0577 - val_loss: 0.0521
# Epoch 2/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0311 - val_loss: 0.0218
# Epoch 3/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0205 - val_loss: 0.0192
# Epoch 4/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0188 - val_loss: 0.0183
# Epoch 5/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0185 - val_loss: 0.0199
# Epoch 6/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0177 - val_loss: 0.0172
# Epoch 7/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0173 - val_loss: 0.0168
# Epoch 8/100
# 396/396 [==============================] - 4s 9ms/step - loss: 0.0171 - val_loss: 0.0165
# Epoch 9/100
# 396/396 [==============================] - 4s 9ms/step - loss: 0.0170 - val_loss: 0.0164
# Epoch 10/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0167 - val_loss: 0.0163
# Epoch 11/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0165 - val_loss: 0.0165
# Epoch 12/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0164 - val_loss: 0.0162
# Epoch 13/100
# 396/396 [==============================] - 4s 11ms/step - loss: 0.0163 - val_loss: 0.0165
# Epoch 14/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0161 - val_loss: 0.0158
# Epoch 15/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0161 - val_loss: 0.0159
# Epoch 16/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0159 - val_loss: 0.0158
# Epoch 17/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0159 - val_loss: 0.0161
# Epoch 18/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0158 - val_loss: 0.0159
# Epoch 19/100
# 396/396 [==============================] - 5s 12ms/step - loss: 0.0157 - val_loss: 0.0156
# Epoch 20/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0155 - val_loss: 0.0157
# Epoch 21/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0154 - val_loss: 0.0154
# Epoch 22/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0155 - val_loss: 0.0157
# Epoch 23/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0154 - val_loss: 0.0152
# Epoch 24/100
# 396/396 [==============================] - 4s 9ms/step - loss: 0.0153 - val_loss: 0.0154
# Epoch 25/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0152 - val_loss: 0.0153
# Epoch 26/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0151 - val_loss: 0.0154
# Epoch 27/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0150 - val_loss: 0.0153
# Epoch 28/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0149 - val_loss: 0.0153
# Epoch 29/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0148 - val_loss: 0.0153
# Epoch 30/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0148 - val_loss: 0.0157
# Epoch 31/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0146 - val_loss: 0.0153
# Epoch 32/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0146 - val_loss: 0.0152
# Epoch 33/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0145 - val_loss: 0.0152
# Epoch 34/100
# 396/396 [==============================] - 4s 9ms/step - loss: 0.0144 - val_loss: 0.0156
# Epoch 35/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0144 - val_loss: 0.0155
# Epoch 36/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0144 - val_loss: 0.0152
# Epoch 37/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0142 - val_loss: 0.0151
# Epoch 38/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0141 - val_loss: 0.0152
# Epoch 39/100
# 396/396 [==============================] - 4s 9ms/step - loss: 0.0140 - val_loss: 0.0151
# Epoch 40/100
# 396/396 [==============================] - 4s 9ms/step - loss: 0.0139 - val_loss: 0.0153
# Epoch 41/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0138 - val_loss: 0.0152
# Epoch 42/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0137 - val_loss: 0.0153
# Epoch 43/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0136 - val_loss: 0.0153
# Epoch 44/100
# 396/396 [==============================] - 4s 9ms/step - loss: 0.0135 - val_loss: 0.0152
# Epoch 45/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0134 - val_loss: 0.0157
# Epoch 46/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0133 - val_loss: 0.0153
# Epoch 47/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0134 - val_loss: 0.0217
# Epoch 48/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0132 - val_loss: 0.0154
# Epoch 49/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0130 - val_loss: 0.0155
# Epoch 50/100
# 396/396 [==============================] - 4s 9ms/step - loss: 0.0129 - val_loss: 0.0154
# Epoch 51/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0128 - val_loss: 0.0155
# Epoch 52/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0126 - val_loss: 0.0156
# Epoch 53/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0125 - val_loss: 0.0156
# Epoch 54/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0124 - val_loss: 0.0156
# Epoch 55/100
# 396/396 [==============================] - 4s 9ms/step - loss: 0.0123 - val_loss: 0.0158
# Epoch 56/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0122 - val_loss: 0.0160
# Epoch 57/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0121 - val_loss: 0.0159
# Epoch 58/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0119 - val_loss: 0.0158
# Epoch 59/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0119 - val_loss: 0.0159
# Epoch 60/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0117 - val_loss: 0.0161
# Epoch 61/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0116 - val_loss: 0.0160
# Epoch 62/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0115 - val_loss: 0.0161
# Epoch 63/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0113 - val_loss: 0.0162
# Epoch 64/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0112 - val_loss: 0.0163
# Epoch 65/100
# 396/396 [==============================] - 4s 9ms/step - loss: 0.0111 - val_loss: 0.0162
# Epoch 66/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0110 - val_loss: 0.0165
# Epoch 67/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0109 - val_loss: 0.0166
# Epoch 68/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0109 - val_loss: 0.0165
# Epoch 69/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0107 - val_loss: 0.0167
# Epoch 70/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0106 - val_loss: 0.0167
# Epoch 71/100
# 396/396 [==============================] - 4s 9ms/step - loss: 0.0105 - val_loss: 0.0167
# Epoch 72/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0104 - val_loss: 0.0170
# Epoch 73/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0103 - val_loss: 0.0168
# Epoch 74/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0102 - val_loss: 0.0170
# Epoch 75/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0100 - val_loss: 0.0171
# Epoch 76/100
# 396/396 [==============================] - 4s 10ms/step - loss: 0.0100 - val_loss: 0.0172
# Epoch 77/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0099 - val_loss: 0.0172
# Epoch 78/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0098 - val_loss: 0.0171
# Epoch 79/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0096 - val_loss: 0.0175
# Epoch 80/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0096 - val_loss: 0.0175
# Epoch 81/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0095 - val_loss: 0.0175
# Epoch 82/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0094 - val_loss: 0.0176
# Epoch 83/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0093 - val_loss: 0.0177
# Epoch 84/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0093 - val_loss: 0.0178
# Epoch 85/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0091 - val_loss: 0.0177
# Epoch 86/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0090 - val_loss: 0.0178
# Epoch 87/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0089 - val_loss: 0.0178
# Epoch 88/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0088 - val_loss: 0.0180
# Epoch 89/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0087 - val_loss: 0.0182
# Epoch 90/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0087 - val_loss: 0.0181
# Epoch 91/100
# 396/396 [==============================] - 4s 9ms/step - loss: 0.0086 - val_loss: 0.0182
# Epoch 92/100
# 396/396 [==============================] - 3s 9ms/step - loss: 0.0085 - val_loss: 0.0183
# Epoch 93/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0084 - val_loss: 0.0184
# Epoch 94/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0083 - val_loss: 0.0186
# Epoch 95/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0083 - val_loss: 0.0185
# Epoch 96/100
# 396/396 [==============================] - 4s 9ms/step - loss: 0.0082 - val_loss: 0.0185
# Epoch 97/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0081 - val_loss: 0.0188
# Epoch 98/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0081 - val_loss: 0.0187
# Epoch 99/100
# 396/396 [==============================] - 3s 7ms/step - loss: 0.0080 - val_loss: 0.0189
# Epoch 100/100
# 396/396 [==============================] - 3s 8ms/step - loss: 0.0079 - val_loss: 0.0189
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 16, 16, 64)        640
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 128)         73856
#
# =================================================================
# Total params: 74496 (291.00 KB)
# Trainable params: 74496 (291.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# The time of execution of above program is : 388.75960302352905 seconds
