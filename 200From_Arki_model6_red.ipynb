# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/binarization-lowres/blob/main/200From_Arki_model6_red.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/Architectural_designs/From Arki/"

# %%
from PIL import Image

# Open the image
image = Image.open(file_path + "200 DPI/Rizal_input.png")

# Convert the image
image = image.convert("RGB")

# Split image to channels
r, g, b = image.split()

# Save the channels to separate images
r.save(file_path +"red200_Rizal_input.png")
g.save(file_path +"green200_Rizal_input.png")
b.save(file_path +"blue200_Rizal_input.png")

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

epoch = 100
model_number = 6
size = 128

def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.66):
        for i in np.arange(0,int(width/size)+1,0.66):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)


    return data

def crop_(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.66):
        for i in np.arange(0,int(width/size)+1,0.66):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            #im1 = im1/4
            data.append(im1)


    return data



input = np.array(crop_(ImageOps.grayscale(Image.open(file_path + "200red_Rizal_input.png"))))
print("Done reading the input of size = ", input.shape)

output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "200Rizal_output.png"))))
print("Done reading the output of size = ", input.shape)

train_input = []
test_input = []
for i in range(0,len(input)):
    if i % 4 == 0:
        test_input.append(input[i])
    else:
        train_input.append(input[i])

train_input = np.array(train_input)
test_input = np.array(test_input)

print("Done reading the train input of size = ", train_input.shape)
print("Done reading the test input of size = ", test_input.shape)

train_output = []
test_output = []
for i in range(0,len(output)):
    if i % 4 == 0:
        test_output.append(output[i])
    else:
        train_output.append(output[i])

train_output = np.array(train_output)
test_output = np.array(test_output)

print("Done reading the train output of size = ", train_input.shape)
print("Done reading the test output of size = ", test_input.shape)
# Out:
# Done reading the input of size =  (16632, 128, 128)
# Done reading the output of size =  (16632, 128, 128)
# Done reading the train input of size =  (12474, 128, 128)
# Done reading the test input of size =  (4158, 128, 128)
# Done reading the train output of size =  (12474, 128, 128)
# Done reading the test output of size =  (4158, 128, 128)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((train_input[i+6000]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+6000]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
start = time.time()
import tensorflow as tf

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model



class autoenc(Model):
  def __init__(self):
    super(autoenc, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Input(shape=(size, size, 1)),
      layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=2)])

    self.decoder = tf.keras.Sequential([
      layers.Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = autoenc()


autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

model = autoencoder.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output))

autoencoder.encoder.summary()


autoencoder.save(file_path + '1 Models/' + 'autoencoder_' + str(model_number)+'_red')

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + '2 Loss/'+'loss_'+ str(model_number) + '_red.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path + '3 Validation loss/' +'val_loss_'+ str(model_number) + '_red.csv')

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")
# Out:
# Epoch 1/100
# 390/390 [==============================] - 29s 46ms/step - loss: 0.0405 - val_loss: 0.0279
# Epoch 2/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0262 - val_loss: 0.0271
# Epoch 3/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0258 - val_loss: 0.0252
# Epoch 4/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0254 - val_loss: 0.0259
# Epoch 5/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0251 - val_loss: 0.0249
# Epoch 6/100
# 390/390 [==============================] - 17s 42ms/step - loss: 0.0250 - val_loss: 0.0246
# Epoch 7/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0247 - val_loss: 0.0241
# Epoch 8/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0243 - val_loss: 0.0243
# Epoch 9/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0241 - val_loss: 0.0237
# Epoch 10/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0239 - val_loss: 0.0235
# Epoch 11/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0237 - val_loss: 0.0235
# Epoch 12/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0237 - val_loss: 0.0241
# Epoch 13/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0234 - val_loss: 0.0234
# Epoch 14/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0233 - val_loss: 0.0235
# Epoch 15/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0232 - val_loss: 0.0231
# Epoch 16/100
# 390/390 [==============================] - 17s 42ms/step - loss: 0.0231 - val_loss: 0.0229
# Epoch 17/100
# 390/390 [==============================] - 17s 42ms/step - loss: 0.0230 - val_loss: 0.0229
# Epoch 18/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0231 - val_loss: 0.0226
# Epoch 19/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0228 - val_loss: 0.0233
# Epoch 20/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0228 - val_loss: 0.0226
# Epoch 21/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0227 - val_loss: 0.0226
# Epoch 22/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0226 - val_loss: 0.0224
# Epoch 23/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0227 - val_loss: 0.0229
# Epoch 24/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0226 - val_loss: 0.0223
# Epoch 25/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0226 - val_loss: 0.0223
# Epoch 26/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0226 - val_loss: 0.0224
# Epoch 27/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0225 - val_loss: 0.0225
# Epoch 28/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0225 - val_loss: 0.0223
# Epoch 29/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0224 - val_loss: 0.0223
# Epoch 30/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0224 - val_loss: 0.0221
# Epoch 31/100
# 390/390 [==============================] - 17s 42ms/step - loss: 0.0224 - val_loss: 0.0222
# Epoch 32/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0224 - val_loss: 0.0220
# Epoch 33/100
# 390/390 [==============================] - 17s 42ms/step - loss: 0.0223 - val_loss: 0.0222
# Epoch 34/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0223 - val_loss: 0.0221
# Epoch 35/100
# 390/390 [==============================] - 17s 42ms/step - loss: 0.0222 - val_loss: 0.0220
# Epoch 36/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0222 - val_loss: 0.0220
# Epoch 37/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0222 - val_loss: 0.0220
# Epoch 38/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0222 - val_loss: 0.0220
# Epoch 39/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0221 - val_loss: 0.0223
# Epoch 40/100
# 390/390 [==============================] - 17s 42ms/step - loss: 0.0221 - val_loss: 0.0220
# Epoch 41/100
# 390/390 [==============================] - 17s 42ms/step - loss: 0.0221 - val_loss: 0.0218
# Epoch 42/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0220 - val_loss: 0.0224
# Epoch 43/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0220 - val_loss: 0.0219
# Epoch 44/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0220 - val_loss: 0.0221
# Epoch 45/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0221 - val_loss: 0.0218
# Epoch 46/100
# 390/390 [==============================] - 17s 42ms/step - loss: 0.0220 - val_loss: 0.0217
# Epoch 47/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0219 - val_loss: 0.0221
# Epoch 48/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0220 - val_loss: 0.0223
# Epoch 49/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0219 - val_loss: 0.0218
# Epoch 50/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0219 - val_loss: 0.0217
# Epoch 51/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0218 - val_loss: 0.0223
# Epoch 52/100
# 390/390 [==============================] - 17s 42ms/step - loss: 0.0218 - val_loss: 0.0217
# Epoch 53/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0218 - val_loss: 0.0223
# Epoch 54/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0218 - val_loss: 0.0217
# Epoch 55/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0217 - val_loss: 0.0216
# Epoch 56/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0219 - val_loss: 0.0216
# Epoch 57/100
# 390/390 [==============================] - 17s 42ms/step - loss: 0.0217 - val_loss: 0.0220
# Epoch 58/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0218 - val_loss: 0.0219
# Epoch 59/100
# 390/390 [==============================] - 17s 42ms/step - loss: 0.0217 - val_loss: 0.0216
# Epoch 60/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0217 - val_loss: 0.0215
# Epoch 61/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0217 - val_loss: 0.0216
# Epoch 62/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0217 - val_loss: 0.0216
# Epoch 63/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0217 - val_loss: 0.0215
# Epoch 64/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0216 - val_loss: 0.0214
# Epoch 65/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0216 - val_loss: 0.0219
# Epoch 66/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0217 - val_loss: 0.0215
# Epoch 67/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0217 - val_loss: 0.0214
# Epoch 68/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0216 - val_loss: 0.0214
# Epoch 69/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0216 - val_loss: 0.0214
# Epoch 70/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0216 - val_loss: 0.0214
# Epoch 71/100
# 390/390 [==============================] - 17s 42ms/step - loss: 0.0216 - val_loss: 0.0214
# Epoch 72/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0216 - val_loss: 0.0218
# Epoch 73/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0215 - val_loss: 0.0214
# Epoch 74/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0216 - val_loss: 0.0215
# Epoch 75/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0216 - val_loss: 0.0215
# Epoch 76/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0216 - val_loss: 0.0217
# Epoch 77/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0215 - val_loss: 0.0217
# Epoch 78/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0216 - val_loss: 0.0215
# Epoch 79/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0216 - val_loss: 0.0213
# Epoch 80/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0215 - val_loss: 0.0213
# Epoch 81/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0215 - val_loss: 0.0215
# Epoch 82/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0216 - val_loss: 0.0214
# Epoch 83/100
# 390/390 [==============================] - 17s 42ms/step - loss: 0.0215 - val_loss: 0.0219
# Epoch 84/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0215 - val_loss: 0.0219
# Epoch 85/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0215 - val_loss: 0.0213
# Epoch 86/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0215 - val_loss: 0.0215
# Epoch 87/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0215 - val_loss: 0.0216
# Epoch 88/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0215 - val_loss: 0.0213
# Epoch 89/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0216 - val_loss: 0.0218
# Epoch 90/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0215 - val_loss: 0.0213
# Epoch 91/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0215 - val_loss: 0.0215
# Epoch 92/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0215 - val_loss: 0.0215
# Epoch 93/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0215 - val_loss: 0.0212
# Epoch 94/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0214 - val_loss: 0.0213
# Epoch 95/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0214 - val_loss: 0.0213
# Epoch 96/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0215 - val_loss: 0.0213
# Epoch 97/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0214 - val_loss: 0.0213
# Epoch 98/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0214 - val_loss: 0.0213
# Epoch 99/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0214 - val_loss: 0.0216
# Epoch 100/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.0214 - val_loss: 0.0214
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 64)        640
#
# =================================================================
# Total params: 640 (2.50 KB)
# Trainable params: 640 (2.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# The time of execution of above program is : 1710.5183703899384 seconds
