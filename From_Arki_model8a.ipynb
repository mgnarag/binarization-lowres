# %% [markdown]
# <a href="https://colab.research.google.com/github/mgnarag/binarization-lowres/blob/main/From_Arki_model8a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ls drive/My\ Drive
file_path = "/content/drive/My Drive/Architectural_designs/From Arki/"

# %%
import time
import pandas as pd


import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf


from PIL import Image, ImageOps
import os
import numpy as np

epoch = 100
model_number = 81
size = 256

def crop(im):
    width, height = im.size
    data = []

    for j in np.arange(0,int(height/size)+1,0.275):
        for i in np.arange(0,int(width/size)+1,0.275):
            im1 = im.crop((0 + (size*i), 0 + (size*j), size + (size*i), size + (size*j)))
            im1 = np.array(im1)
            im1 = im1.astype(np.float32)
            im1 = im1/255
            data.append(im1)
    return data




train_input = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Rizal_input_train.png"))))
print("Done reading the  training input of size = ", train_input.shape)

train_output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Rizal_output_train.png"))))
print("Done reading the  training out of size = ", train_output.shape)

test_input = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Rizal_input_test.png"))))
print("Done reading the  test input of size = ", test_input.shape)

test_output = np.array(crop(ImageOps.grayscale(Image.open(file_path + "Rizal_output_test.png"))))
print("Done reading the  test output of size = ", test_output.shape)
# Out:
# Done reading the  training input of size =  (4368, 256, 256)
# Done reading the  training out of size =  (4368, 256, 256)
# Done reading the  test input of size =  (2090, 256, 256)
# Done reading the  test output of size =  (2090, 256, 256)

# %%
n = 10
plt.figure(figsize=(10, 4))
for i in range(0,10):

    ax = plt.subplot(2, n, i + 1)
    plt.title("input")
    plt.imshow((train_input[i+2000]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    bx = plt.subplot(2, n, i + n + 1)
    plt.title("output")
    plt.imshow((train_output[i+2000]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)
plt.show()

# %%
start = time.time()
import tensorflow as tf

from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model

class autoenc(Model):
  def __init__(self):
    super(autoenc, self).__init__()
    self.encoder = tf.keras.Sequential([
      layers.Input(shape=(size, size, 1)),
      layers.Conv2D(64, (3, 3), activation='relu', padding='same', strides=2)])

    self.decoder = tf.keras.Sequential([
      layers.Conv2DTranspose(64, kernel_size=3, strides=2, activation='relu', padding='same'),
      layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same')])

  def call(self, x):
    encoded = self.encoder(x)
    decoded = self.decoder(encoded)
    return decoded

autoencoder = autoenc()


autoencoder.compile(optimizer='adam', loss=losses.MeanSquaredError())

model = autoencoder.fit(train_input, train_output,
                epochs=epoch,
                shuffle=True,
                validation_data=(test_input, test_output))

autoencoder.encoder.summary()



autoencoder.save(file_path + '1 Models/' + 'autoencoder_' + str(model_number))

loss = model.history['loss']
loss = pd.DataFrame(loss)
loss.to_csv(file_path + '2 Loss/'+'loss_' + str(model_number)+'.csv')
val_loss = model.history['val_loss']
val_loss = pd.DataFrame(val_loss)
val_loss.to_csv(file_path + '3 Validation loss/' +'val_loss_' + str(model_number)+'.csv')

# record end time
end = time.time()

print("The time of execution of above program is :",
      (end-start), "seconds")
# Out:
# Epoch 1/100
# 137/137 [==============================] - 40s 199ms/step - loss: 0.0769 - val_loss: 0.0364
# Epoch 2/100
# 137/137 [==============================] - 23s 170ms/step - loss: 0.0266 - val_loss: 0.0380
# Epoch 3/100
# 137/137 [==============================] - 23s 171ms/step - loss: 0.0246 - val_loss: 0.0302
# Epoch 4/100
# 137/137 [==============================] - 24s 175ms/step - loss: 0.0234 - val_loss: 0.0378
# Epoch 5/100
# 137/137 [==============================] - 24s 176ms/step - loss: 0.0226 - val_loss: 0.0403
# Epoch 6/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0217 - val_loss: 0.0291
# Epoch 7/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0211 - val_loss: 0.0221
# Epoch 8/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0205 - val_loss: 0.0297
# Epoch 9/100
# 137/137 [==============================] - 24s 175ms/step - loss: 0.0200 - val_loss: 0.0298
# Epoch 10/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0197 - val_loss: 0.0236
# Epoch 11/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0194 - val_loss: 0.0260
# Epoch 12/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0191 - val_loss: 0.0268
# Epoch 13/100
# 137/137 [==============================] - 24s 175ms/step - loss: 0.0191 - val_loss: 0.0326
# Epoch 14/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0191 - val_loss: 0.0296
# Epoch 15/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0188 - val_loss: 0.0272
# Epoch 16/100
# 137/137 [==============================] - 24s 179ms/step - loss: 0.0187 - val_loss: 0.0217
# Epoch 17/100
# 137/137 [==============================] - 24s 179ms/step - loss: 0.0187 - val_loss: 0.0220
# Epoch 18/100
# 137/137 [==============================] - 24s 178ms/step - loss: 0.0186 - val_loss: 0.0304
# Epoch 19/100
# 137/137 [==============================] - 24s 178ms/step - loss: 0.0186 - val_loss: 0.0314
# Epoch 20/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0184 - val_loss: 0.0164
# Epoch 21/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0184 - val_loss: 0.0192
# Epoch 22/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0183 - val_loss: 0.0204
# Epoch 23/100
# 137/137 [==============================] - 24s 175ms/step - loss: 0.0182 - val_loss: 0.0211
# Epoch 24/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0181 - val_loss: 0.0198
# Epoch 25/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0181 - val_loss: 0.0180
# Epoch 26/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0180 - val_loss: 0.0195
# Epoch 27/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0179 - val_loss: 0.0171
# Epoch 28/100
# 137/137 [==============================] - 24s 173ms/step - loss: 0.0179 - val_loss: 0.0225
# Epoch 29/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0179 - val_loss: 0.0181
# Epoch 30/100
# 137/137 [==============================] - 24s 178ms/step - loss: 0.0178 - val_loss: 0.0155
# Epoch 31/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0178 - val_loss: 0.0178
# Epoch 32/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0177 - val_loss: 0.0150
# Epoch 33/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0177 - val_loss: 0.0166
# Epoch 34/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0177 - val_loss: 0.0181
# Epoch 35/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0176 - val_loss: 0.0183
# Epoch 36/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0176 - val_loss: 0.0174
# Epoch 37/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0177 - val_loss: 0.0219
# Epoch 38/100
# 137/137 [==============================] - 24s 179ms/step - loss: 0.0176 - val_loss: 0.0176
# Epoch 39/100
# 137/137 [==============================] - 24s 175ms/step - loss: 0.0175 - val_loss: 0.0170
# Epoch 40/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0175 - val_loss: 0.0189
# Epoch 41/100
# 137/137 [==============================] - 24s 173ms/step - loss: 0.0176 - val_loss: 0.0167
# Epoch 42/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0175 - val_loss: 0.0227
# Epoch 43/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0175 - val_loss: 0.0145
# Epoch 44/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0175 - val_loss: 0.0160
# Epoch 45/100
# 137/137 [==============================] - 24s 178ms/step - loss: 0.0174 - val_loss: 0.0146
# Epoch 46/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0174 - val_loss: 0.0186
# Epoch 47/100
# 137/137 [==============================] - 24s 175ms/step - loss: 0.0173 - val_loss: 0.0160
# Epoch 48/100
# 137/137 [==============================] - 24s 178ms/step - loss: 0.0174 - val_loss: 0.0207
# Epoch 49/100
# 137/137 [==============================] - 24s 175ms/step - loss: 0.0173 - val_loss: 0.0159
# Epoch 50/100
# 137/137 [==============================] - 24s 175ms/step - loss: 0.0173 - val_loss: 0.0163
# Epoch 51/100
# 137/137 [==============================] - 24s 175ms/step - loss: 0.0173 - val_loss: 0.0179
# Epoch 52/100
# 137/137 [==============================] - 24s 175ms/step - loss: 0.0172 - val_loss: 0.0180
# Epoch 53/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0172 - val_loss: 0.0154
# Epoch 54/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0172 - val_loss: 0.0186
# Epoch 55/100
# 137/137 [==============================] - 24s 175ms/step - loss: 0.0171 - val_loss: 0.0155
# Epoch 56/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0171 - val_loss: 0.0182
# Epoch 57/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0171 - val_loss: 0.0154
# Epoch 58/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0171 - val_loss: 0.0157
# Epoch 59/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 60/100
# 137/137 [==============================] - 24s 175ms/step - loss: 0.0172 - val_loss: 0.0167
# Epoch 61/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0171 - val_loss: 0.0174
# Epoch 62/100
# 137/137 [==============================] - 24s 173ms/step - loss: 0.0170 - val_loss: 0.0173
# Epoch 63/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0170 - val_loss: 0.0185
# Epoch 64/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0170 - val_loss: 0.0168
# Epoch 65/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0170 - val_loss: 0.0152
# Epoch 66/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0169 - val_loss: 0.0158
# Epoch 67/100
# 137/137 [==============================] - 24s 178ms/step - loss: 0.0169 - val_loss: 0.0198
# Epoch 68/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0169 - val_loss: 0.0138
# Epoch 69/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0169 - val_loss: 0.0150
# Epoch 70/100
# 137/137 [==============================] - 24s 178ms/step - loss: 0.0169 - val_loss: 0.0164
# Epoch 71/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0168 - val_loss: 0.0148
# Epoch 72/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0168 - val_loss: 0.0157
# Epoch 73/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0169 - val_loss: 0.0158
# Epoch 74/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0168 - val_loss: 0.0152
# Epoch 75/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0168 - val_loss: 0.0155
# Epoch 76/100
# 137/137 [==============================] - 24s 178ms/step - loss: 0.0168 - val_loss: 0.0166
# Epoch 77/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0168 - val_loss: 0.0139
# Epoch 78/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0168 - val_loss: 0.0141
# Epoch 79/100
# 137/137 [==============================] - 24s 173ms/step - loss: 0.0168 - val_loss: 0.0144
# Epoch 80/100
# 137/137 [==============================] - 24s 178ms/step - loss: 0.0167 - val_loss: 0.0152
# Epoch 81/100
# 137/137 [==============================] - 24s 178ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 82/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0167 - val_loss: 0.0166
# Epoch 83/100
# 137/137 [==============================] - 24s 178ms/step - loss: 0.0167 - val_loss: 0.0140
# Epoch 84/100
# 137/137 [==============================] - 24s 178ms/step - loss: 0.0167 - val_loss: 0.0150
# Epoch 85/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0166 - val_loss: 0.0159
# Epoch 86/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0166 - val_loss: 0.0167
# Epoch 87/100
# 137/137 [==============================] - 24s 173ms/step - loss: 0.0166 - val_loss: 0.0135
# Epoch 88/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0166 - val_loss: 0.0137
# Epoch 89/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0166 - val_loss: 0.0148
# Epoch 90/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0166 - val_loss: 0.0145
# Epoch 91/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0166 - val_loss: 0.0131
# Epoch 92/100
# 137/137 [==============================] - 24s 173ms/step - loss: 0.0166 - val_loss: 0.0145
# Epoch 93/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0165 - val_loss: 0.0166
# Epoch 94/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0166 - val_loss: 0.0141
# Epoch 95/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0165 - val_loss: 0.0136
# Epoch 96/100
# 137/137 [==============================] - 24s 173ms/step - loss: 0.0165 - val_loss: 0.0154
# Epoch 97/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0165 - val_loss: 0.0164
# Epoch 98/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0165 - val_loss: 0.0149
# Epoch 99/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0164 - val_loss: 0.0167
# Epoch 100/100
# 137/137 [==============================] - 24s 174ms/step - loss: 0.0164 - val_loss: 0.0143
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 128, 64)      640
#
# =================================================================
# Total params: 640 (2.50 KB)
# Trainable params: 640 (2.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# The time of execution of above program is : 2420.1649045944214 seconds
